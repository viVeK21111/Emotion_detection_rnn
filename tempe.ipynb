# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import re

# %%
df = pd.read_csv('data/tweet_emotions.csv')
df
# Out:
#          tweet_id   sentiment  \
# 0      1956967341       empty
# 1      1956967666     sadness
# 2      1956967696     sadness
# 3      1956967789  enthusiasm
# 4      1956968416     neutral
# ...           ...         ...
# 39995  1753918954     neutral
# 39996  1753919001        love
# 39997  1753919005        love
# 39998  1753919043   happiness
# 39999  1753919049        love
#
#                                                  content
# 0      @tiffanylue i know  i was listenin to bad habi...
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 3                   wants to hang out with friends SOON!
# 4      @dannycastillo We want to trade with someone w...
# ...                                                  ...
# 39995                                   @JohnLloydTaylor
# 39996                     Happy Mothers Day  All my love
# 39997  Happy Mother's Day to all the mommies out ther...
# 39998  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999  @mopedronin bullet train from tokyo    the gf ...
#
# [40000 rows x 3 columns]

# %%
df.info() # no null values detected
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet_id   40000 non-null  int64
#  1   sentiment  40000 non-null  object
#  2   content    40000 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 937.6+ KB

# %% [markdown]
# ### Preprocessing the data

# %%
import re
li = []
for x in df['content']:
    x = re.sub(r'http\S+|www\S+|http\S+','', x, flags=re.MULTILINE)
    x = re.sub(r'\.',' ',x)
    x = re.sub(r'([?!.,])\1+', r'\1', x)  # removes duplicacy like ??? with ?
    x = re.sub(r'(\w)\1{1,}', r'\1', x) # replaces words like soooo with so
    x = re.sub(r'\b[a-zA-Z]+\*+\w*\b','Anger',x) # remove words which starts with a alphabet and contains any * after 
    x = re.sub(r'[^a-zA-Z0-9\s\!\?\,\@\']','',x)  # remove any other symbols other than space,.,!,?
    x = re.sub(r'\b(\S+?)([^\w\s]*\s+\1\b)+', r'\1', x) # removing repeated words. ex: F! F! F! to F!
    x = re.sub(r'@\S+','[<name>]',x) # replacing names with entity [NAME]
    li.append(x)

# %%
li
# Out:
# ['[<name>] i know  i was listenin to bad habit earlier and i started freakin at his part ',
#  'Layin n bed with a headache  ugh   waitin on your cal   ',
#  'Funeral ceremony   glomy friday   ',
#  'wants to hang out with friends SON!',
#  '[<name>] We want to trade with someone who has Houston tickets, but no one wil ',
#  "Repinging [<name>] why didn't you go to prom? BC my bf didn't like my friends",
#  "I should be slep, but im not! thinking about an old friend who I want  but he's maried now  damn, amp he wants me 2! scandalous!",
#  'Hm   is down',
#  '[<name>] Charlene my love  I mis you',
#  "[<name>] I'm sory  at least it's Friday?",
#  'cant fal aslep',
#  'Choked on her retainers',
#  'Ugh! I have to beat this stupid song to get to the next  rude!',
#  '[<name>] if u watch the hils in london u wil realise what tourture it is because were weks and weks late  i just watch itonlinelol',
#  'Got the news',
#  'The storm is here and the electricity is gone',
#  '[<name>] agred',
#  "So slepy again and it's not even that late  I fail once again ",
#  '[<name>] lady gaga tweted about not being impresed by her video leaking just so you know',
#  'How are YOU convinced that I have always wanted you? What signals did I give of   damn I think I just lost another friend',
#  "[<name>] oh to bad! I hope it gets beter  I've ben having slep isues lately to",
#  "Wondering why I'm awake at 7am,writing a new song,ploting my evil secret plots muahahaha   oh damn it,not secret anymore",
#  'No Topic Maps talks at the Balisage Markup Conference 209   Program online at  via [<name>] topicmaps',
#  "I ate Something I don't know what it is    Why do I kep Teling things about fod",
#  "so tired and i think i'm definitely going to get an ear infection   going to bed quotearlyquot for once ",
#  'On my way home n having 2 deal w underage girls drinking gin on da bus while talking bout kegers      damn i fel old',
#  "[<name>]  i'm sory people are so rude to you, isac, they should get some maners and know beter than to be so lewd!",
#  'Dam servers stil down  i ned to hit 80 before al the koxpers pas me',
#  "Fudge     Just BS'd that whole paper     So tired     Ugh I hate schol       time to slep!",
#  'I HATE CANCER  I HATE IT I HATE IT I HATE IT ',
#  'It is so anoying when she starts typing on her computer in the midle of the night!',
#  '[<name>] i cant slep',
#  'I mised the Anger bus!',
#  'fels strong contractions but wants to go out   ',
#  'SoCal!  stoked  or maybe not   tomorow',
#  'Screw you [<name>] I only have 3 weks   ',
#  "[<name>] yeah S i fel al funy cause i haven't slept enough  i woke my mum up cause i was singing she's not impresed S you?",
#  'I ned skot right now',
#  'has work this afternon',
#  '[<name>] Aw you would not unfolow me would you? Then I would cry',
#  "m much beter day    so far! it's stil quite early  last day of uds",
#  '[<name>] lt3 your gona be the first  twiter  cause your amazing lol  come to canada  would do anything to se you perform',
#  'just picked up her Blackbery from the midle of the stret! Both she and it are crushed!',
#  "Why do I have the feling I should be packing and hiting for SFO around this time of the year? I think I'm mising something   ",
#  '[<name>] midle schol and elem  High schols wil remain open for those who ned credits to graduate  Cali is broken',
#  "Bed!    its time,      hope i go to schol tomorow, al though i don't fel very wel right now",
#  '[<name>] Ah       Wel, I was hoping that I could learn some stuf on the way      Why not you and I work on separate things but also',
#  "I'm having a problem with my photo here in twiter amf!   can't se my face!",
#  "[<name>] oh no!  if i blow a tire you're realy going to have to send up some batman smoke ",
#  'wna take a bath!',
#  'Chocolate milk is so much beter through a straw  I lack said straw',
#  'why am i so tired?',
#  '[<name>] hey yu lil fucker i textd yu',
#  "[<name>] time dif and i've just ben wraped up in day to day stuf so i havent ben tweting  talk son,must slep   up in 6hrs",
#  '[<name>]  no way! damn that sucks B!  are you ok?',
#  'sucks not being able to take days of work or have the money to take the trip  so sad',
#  'bed   sorta  today was god, sara has strep thought Angelina does to i shared a water with her B4 they told me, i wil prob get it to',
#  "[<name>] the recesion  her hotel are restructuring how the acounts are done  ads a bit more presure in the short term but we'l cope",
#  '[<name>] But I got dibs on Sulu   ',
#  '[<name>] Aw  Onward and upwards now, yay! Stil sad to leave I bet ',
#  '[<name>] at once haha   por aby stil gets sore!',
#  "diesel yaris    70mpg  so sad its not available in the US  That'd be awesome ",
#  'I want to buy this great album but unfortunately i dont hav enuf funds  its quotlong time noisyquot',
#  '[<name>]  in al honesty   pain   blech ',
#  "Ok     the pasengers     no one is alive     they're al dead     you just don't know it til the end     then you cry    ",
#  'At home alone with not much to do',
#  "[<name>] ia so much! i haven't realy ben hapy with any of coks choices for singles ",
#  "[<name>] [<name>]  i fel aslep on the beach and didn't put on enough sunscren  lol",
#  'So i think my son might have the flu cause I def  just cleaned up a stanky puke mes  Por pumkpin',
#  'So great to se Oin amp Cynthia   So hapy   Diner was great, cute litle place   To bad Oin got sick afterwards ',
#  'I cant give [<name>] any bday nudges ',
#  "   and al woman who transfer their first impresions sexualmaternal onto a les 'threatening' man  are themselves as weak as 'Him'",
#  "Brothers Blom won't be opening this wekend in El Paso   I'l just buy Brick and enjoy that until I can watch Brothers Blom ",
#  'says I mis plurking   ',
#  'Biten to blod by my cat, on my way for a rabies bacterin  Sems 7 shots for 2 months  Never wash my cats at home again, they hate water',
#  'I mis Vobys!',
#  '[<name>] Neither are ELP!',
#  '[<name>]  dude, that is my favorite sandwich place ever  um did you take PICTURES?',
#  "is sad that shin ae got maried   and it wasn't to alex",
#  "[<name>] Sure you wil twet about this when you're back, but news is abuz about TR Knight's leaving quotconfirmedquot today   Muy triste ",
#  '[<name>] oh thursday i have exams   al day  what about wednesday ?',
#  'there was a mix up with my dentist apt this afternon  so they rescheduled me for tomorow @ 9am ',
#  '[<name>] [<name>] i was just thinking about how excited i am for you guys to move, but then i realized how sad i am to se you go ',
#  'god morning people    sun is out   definitly spring now, we had our first spring hail storm, my car has dimples now  ',
#  "[<name>] I love those 'it'sakey' USB sticks  We only have the 4GB in Australia",
#  'fresh prince and slepy sleps my nightly routine  gota go to Dmv early tmrw',
#  "damit! hulu desktop has totaly screwed up my ability to talk to a particular port on one of our dev servers  so i can't watch and code",
#  '[<name>] i am jealous of your mom talking to [<name>]  i want to se you al our twitering is making me mis you',
#  "I can't slep   I kep thinking about the pupy I played with today",
#  "   I'm suposed to be slep  But i got some much to do  amp i got that one part of the song stuck in my head quotyour a jerk iknowquot  blah",
#  "[<name>] what's going on swetheart?",
#  "How can it be so freaking dificult to get a systemwide spelchecker? Shit, I'd setle for an ofice suite one  Stupid unhelpful Windows",
#  'Last one month due to sumer, strawbery is not availble in the Chenai markets!',
#  '[<name>] work at 6am  Gota go to bed son',
#  '[<name>] corect! I ADORE him  I just plucked him up and put him under my arm cuz he was cryin   Al beter now! Hahaha',
#  '[<name>] hi im on my ipod   i cant fal aslep',
#  'dont wana work 1830 tomorow  but i get paid',
#  'fels sad coz i wasnt able to play with the guys!  ',
#  'PrinceCharming',
#  "@ cayogial i wanted to come to BZ this sumer  not so sure anymore    a teacher's life in the sumer SUCKS",
#  'First ever droped cal on my mobile  On a cal to [<name>] no les!  being charged for data even though I have a data pack  ',
#  '[<name>] You win     SIGH Rakem',
#  'Oh is that time for real?',
#  "Darn these alergies! I don't like this time of year because of this! I never used to have this problem either",
#  'Oh no one minute to late! Oh wel',
#  '[<name>] Damn, that sucks',
#  "[<name>] i wanted to come to BZ this sumer  not so sure anymore    a teacher's life in the sumer SUCKS",
#  '[<name>] THIS WEBSITE GAVE ME A VIRUS! When i opened it more windows kept POPING up',
#  'ah! big scary bug flying around my rom!',
#  'I wish she knew what she puts me through  She stole my heart, never gave it back  and ocasionaly she likes to be like lok what I have!',
#  'is up with a nasty cough i cant be sick i have a huge wekend ahead of me',
#  '[<name>]  That was stone cold   Crazy      ?',
#  "i'm so tired",
#  'shift time  bye biochem wah! ',
#  "[<name>] I'm sure some1 wil cum out and play  I'm workin through til midnight ",
#  '[<name>] I second that  I wish it rained more where I am',
#  "[<name>] early hapy day of birth in case I don't make it! Very tired from therapy today n just taking my medicine!  mishu! Love ya!",
#  'damn it were is Eric or anyone else when you ned your hair to be played with',
#  "I'm fel deflated  Ugh  No more dog ",
#  'Alergies suck ducks nuts      lt8[<name>]',
#  'Wel it almost was a god day    Gues I just retry tomorow',
#  '[<name>] Waraku is tasteles and expensive! Portion is so litle!  re waraku',
#  "[<name>] sounds god  Apreciate the sugestion  Ben a wek now and we're stil ofline  Time to ask for a refund   ",
#  '[<name>] He died   Wait, what about Magic Jack? I just read it ',
#  '[<name>]  youstinkatrespondingtotexts!',
#  'wonders why her Karma points turned into 0   ',
#  'Ned to pack for CALI! Canot wait! Thinking a glas of wine is in order to celebrate my wekend vaca  Stil work 2morow, tho ',
#  'Is miserable  i fel like im gona cry  sux!',
#  '[<name>] wel I ran out of ber so I left  Not sure about the ETA  Waiting waiting  Bleh  Gona be a long nite methinks ',
#  "[<name>] My nose stud fel out and I can't find it  Loks like I'l have to head into Amsterdam today and get a new one",
#  'claire [<name>] love the show, got into the ofice @ 5am and no radio',
#  'Pats in phily at 2 am  I love it  Mm chesesteak   Mis my boyfriend   but I love vacation ',
#  "sigh I'm going to bed    I just don't fel right anymore   ",
#  "What? I focused on Tom so much I didn't se my beloved Barack! Oh no! I must vote for both! Por president only has 626 votes ",
#  '[<name>] EpiCentre Whelock Place  tourists only  ',
#  'Now I am depresed after watching so you think you can dance',
#  "Just cros 'cause I'm stuck twidling my thumbs now, ugh",
#  "mis 16'th",
#  '[<name>] I know  But like I said, I have no idea how long it takes for them to investigate this stuf ',
#  'I cant slep, but im to sore to move',
#  '[<name>]   Awe! I mis my baby',
#  '[<name>] just answered you never learned how to write in French just basic stuf',
#  'what is it with chocolates? i just can never say no',
#  'Achieving a new apreciation on how a xml build script can realy be painful and cumbersome',
#  "[<name>] i'm to awake now  il have a nap this afternon",
#  '[<name>] i cant do anything',
#  'stil neds another 6 hours of slep',
#  "I'm at work",
#  'RIP leonardo  You were a great mini fidler crab',
#  'Morning tweple,way to early again',
#  'Last day working for the Uni today, sad times',
#  "[<name>] thanks nemah  I'm gona be so close to you and izy, yet so far",
#  'My head hurts so bad I could scream!',
#  'i just go up and IM SO TIRED and my airmatras is broken somewhere and now im in even more pain',
#  'New work welnes chalenge not going wel   I comited to not check email betwen 10 pm and 6 am   Failed on first day   Twice',
#  'New blog post Blog auto insuran    I just found that my auto insurance policy had ben expired   I am to careles         Meanw    ',
#  'where are al ma bestfriends at ? , MIA or wat ?',
#  "oh men!      I realy can't se my face        c'mon guys!",
#  "I'm showing my age  Renewed my tags last wek, went down 20  Got my insurance renewal email today, went down 10  I don't wana be old",
#  'my sole suporter is not my sole suporter',
#  "don't you hate it when you finish al your work and there's stil 1 25 hours left of work time",
#  '[<name>] urgh stop it guys',
#  'is stil mising her husband     I realy want him home ',
#  'I mis my pupy',
#  '2 days of this month left, and I only have 40MB left on my onpeak downloads ',
#  "[<name>] Up is out?  I didn't get the memo   It loks amazing ",
#  "[<name>] I've given up on piza  kids would never let me have my fav  the hot ones",
#  "Up reading tabloids about other people's lives   thinking what I'm gona do with mine when my baby leaves?",
#  '[<name>] yearling in pet home died    very sad for their whole family',
#  "fun in the sun hm hel no it's cold",
#  'I got a giant splinter stuck up underneath my finger nail today at Mupets   it hurt   But I got to go to First Aid for the first time!',
#  "[<name>] We hate change, so of course  We're fans for life  lt3 Oh and if we haven't met Rob by then something went horibly wrong ",
#  'is feling sad    for some reason    ',
#  "wel fuck this new pain med has an od warning that actualy aplies to me  i can't take this  chan is displeased ",
#  'just uploaded my new blog    a painful story about an 80s year old man who cried because he wanted to die    very sad',
#  "[<name>] i don't think so   I WANT DETAILS ",
#  '[<name>] Hi   ! Who is Mary Popins?',
#  '[<name>] Its so adicting, but its kind of a curse to do them at night time  Everytime i do one, i fel like making music afterwards',
#  "my last twet didn't send  bad phone",
#  "[<name>]  OMG Ur alive! LOL  2day has gone so slow  I'm going insane Gr You doing anything tonight?",
#  "Have a headache  I'm going to bed  Godnight!",
#  '[<name>]  I was watching Parental Control',
#  '[<name>] did you get them from california vintage? ahahah they have the BEST dreses, i want them but i dont have ebay',
#  'I just saw pics from this past Thanksgiving and am sad because Grandma was in them ',
#  '[<name>] it wont let me',
#  "Tok a shift tomorow     I don't realy fel like working right now ",
#  'but now i have no money for a phone',
#  'Spent last night in AampE ER  Wife tangled whels with Daughter amp hit the deck  Dislocation amp fracture resulted ',
#  "[<name>] 9 days  I'm about ready to visit Torchwod and se if they've heard anything",
#  "[<name>] where are you? In Bris? I can't hear any thunder",
#  'bec vs fat fod    winer  fat fod  but not this weknend, il beat it!',
#  'To bad the Red Devils   disapointing to say the least',
#  'I had a dream about a prety beach and there was no beach when I woke up',
#  '[<name>] Have a 3ware 9650SE, not fast enough for 3x X25M SD RAID5  80Mhz IOP on the HPT  Might try an Adaptec 5405 1 2Ghz ',
#  'when da heck wil the garage man get here I ask you   WHEN  ',
#  "Ate Mandy, please forgive me  I realy am sory  I don't wana lose my Bf",
#  "[<name>] Um yeah  That's probably a prety god note to self because e",
#  'why are plane tickets so expensive',
#  "[<name>] [<name>] Um yeah  That's probably a prety god note to self because e",
#  'Neds a job BADLY!',
#  '[<name>] damn I do wish I was there ',
#  'Went to Di Bela cofe roasters today and asked for a job      The person I neded to speak to is on holiday     fb',
#  '[<name>] I played up until the later parts of the vodo vilage part coop until I lost my usual partner',
#  "[<name>] Nite  Now I'm up n bored as oposed to almost slep frm b 4",
#  'is a bad friend',
#  "[<name>] hapy birthday! hope you have an awesome day  didn't se you at next last night!",
#  '[<name>] im doing that shit right now     im on vacation and you got me workin',
#  '[<name>] il be over in an oir',
#  "[<name>] gues its a no go girlie  I'm stil at the gym and work at 630am",
#  "would wish the severe migrains would stop! doc's prescriptions arent working",
#  '[<name>] i mised the game',
#  '[<name>] No internet last night ER was bril, there was a masive explosion at the end of a nearby gas works ER on standby',
#  '[<name>] cuz airlines are super lame ',
#  '[<name>]  Stil a pity it comes with no lamb though',
#  "[<name>]  I'm sory to hear that  Here is my optimist Things wil get beter  For al of us ",
#  'is done painting al the bedrom furniture, I stil have to do the table but it wil wait until after the move  Ugh moving in the heat',
#  "I'm so very tired   and have insomnia ",
#  '[<name>] A hungry fol  Il probably never se that Krispy Kreme again  Had to enjoy it  They closing down',
#  '[<name>] airport? and you didnt show up tonight homo!',
#  'I hate Bakersfield and I hate the Ports, let me go home already   I want to start my vacation ',
#  '[<name>] what about me',
#  'Loking for desktop twiter ap that wil actualy let you aces URLs, any sugestions? I liked Twitle but no linking',
#  'people in my house do not know how to close dors',
#  'Why am I completing facebok quizes at this time of the morning    especialy a friday morning',
#  'out with [<name>] amp [<name>] i am so hungry',
#  "[<name>] I don't like the posibility of the left side of my brain hurting because of the thing caled a VP shunt and posible death",
#  'Had to cancel wow for now',
#  "wants to make a music profile but i don't have money i don't know how to write music i don't know how to play an instrument and no studio",
#  "[<name>] But yeah   I'm sad about my quotRavenclawquot acount  I love that acount to bits ",
#  "It's 115 AM, and I hear a helicopter flying over my house  That's kind of weird  In other news, my headache is back  BO ",
#  '[<name>] oh no  i am always here  lt3',
#  "back from schol  Ms Suhana's last day as our FT  OCU was okay  I'm playing ALTNOY over and over again ",
#  '@ pol  was trying to get it to work in a powerpoint to no avail ',
#  'tok a math test today  The day before the test, the teacher says bring your calculator  Luke was confident  Teacher decided no calcs ',
#  'omg, the concert was awesome, madrigals gave me chils on almost every piece   broks also caled up alumni, but i didnt get to go',
#  "[<name>] yeah, it's terible  cockatos are the hardest to live with, so emotional  god thing he found you, though!",
#  'Up late with nothin 2 do     ',
#  'i think the vog is making me sicker than i think  feling slightly achy',
#  '[<name>] i was watching Harpers Island, lol    there was no vodka involved',
#  'i am doing homework it sux big time maths is the worst!',
#  '[<name>] would have ben beter, IMO, if it let you play through al 3 songs provided  I just start to quotget itquot and it blacks out ',
#  '3wordsaftersex it never started   ',
#  'sometimes i wish things could go back to the way they were the begining of last sumer',
#  "I downloaded the new twiterfon update thinking they were fixing the typing problem for new twets, but no, they didn't",
#  "[<name>] Trudy's of Burnet   the one up north that no one goes to",
#  '[<name>] I fel the same way, but I gues no mater where you are there wil always be memes ',
#  'I Cant do 30 minutes of Treadmil  but done 30 minutes for today already, gona do 20 minutes more',
#  "i'm so confused",
#  "With friends like VaikO,Nedumaran, LTE didn't ned enemies  Wrong advice at wrong time led to numerous deaths amp a lost cause as wel",
#  'Work day 7 of 7,',
#  "Chilin with the romies  Can't wait for the zombie CLWN CR  Its gona be 68 weks",
#  'I love guitars, and playing them  I think they sound magnificent  If only i was beter    If only',
#  "[<name>] No refunds but they do retrieve acounts, takes like a wek  Just hoping the thief doesn't use hacks or then it's permaban",
#  '[<name>] no im not  cries LOL',
#  'Cute Malay girl came to semy rom for rent  sadly think it was for her guyfreind   bit misleading and disapointing LOL',
#  '[<name>] EpiCentre Whelock Place, 250 units amp for tourists only  Starting today',
#  'I hate the new mt dew comercial  the one with a giant mosquito  it scares me and groses me out al at the same time ',
#  "Come on Knight    It's ben wel over 4 hours",
#  "not super ken on the drive home through the rain   aditional concentration required that i don't realy wana deal with",
#  "[<name>] aw u can't let me in on the secret!",
#  "[<name>] Im sory  I don't think I stick out, at least compared to what I used to lok like ",
#  'no transport for church  wont be making it, im crushed  Oh wel, more time for asignments I supose  My throat realy hurts    ',
#  'i HATE when i se pregnant women smoking! its so iresponsible n selfish! its sad  ultimately, the baby is the one who sufers ',
#  'Lies   lies    you just cant avoid to lie about practicaly   EVERYTHING!',
#  'twitascope is NOT rocking my socks  go away already!',
#  'Driving Back home because I forgot the piece of cake for [<name>]',
#  "[<name>] so I tried jumping without the trampoline and its like thud  shouldn't have eaten that cokie   ",
#  'Everytime I send an email to my coach, I fel a ned to practice    shity bals   Lol',
#  "It's pising me of and not leting me folow ericka",
#  "Is going to slep not peaceful  wanted to hear him say God Night but that didn't hapen  God Night everyone    ",
#  'my mums trying to make me fel ebter about stoping voting adn not wining shortstack  i almost cried ',
#  '[<name>] i was so close to the tacos   one spot to late',
#  '[<name>] um how bout em?  aint get 2 se da game  but i se dey survived anotha game of da series due to notin but Lebron im guesin',
#  "is thinking so much and i'm at work",
#  'I have forgot the live with the Jonas Brothers on Facebok',
#  "I haven't sen Mufin in two whole days!",
#  "[<name>] i'l mis y'al back    give [<name>] my regards   ",
#  'my gap year is going so quick',
#  "I have to admit, I'm a bit bumed out that I wasn't with my friends walking today    ",
#  '[<name>] girl a blunt is so in my thoughts right now  I had an absolutly GREAT day with a few stresors   come home',
#  'my twiter has ben hacked again',
#  'Just found mj mouse flats at DJs  Of course there are none left in my size',
#  '[<name>] i wont have time to buy  and i ned a new binder pa',
#  '[<name>]  hahaha wel its try its so ugly',
#  '25man Ulduar is hard   ',
#  "[<name>] I don't even want to know WHY you know about VHEMT, but don't go  we'd mis you",
#  "[<name>] That's awesome! We have that this wekend to but I can't go because I'm moving this Sat   I should be a lot of fun though",
#  "night twiter world  stil cant believe the thomas thing  tomorow's guna be FUNSAD",
#  '[<name>] this is hapening to me to',
#  '[<name>] oh no   hugs',
#  "[<name>] bored now because i was talking to someone but now they're busy with something else  just kinda a bumer, idk",
#  "[<name>] i know  things won't be the same lt3",
#  "OMGnes it's 118 pm and I ned to beup early to set up my garage sale it starts a 8am, wish I said 9am  I'm beat ",
#  '[<name>] i kno i do! yal partyin with out me',
#  'Okay, so twiter sudenly changed, how do I respond to mesages now',
#  'ugh   my dad just told me to read an article about Kavya Shivashankar the spelin be girl  and be more like her ',
#  "Decided that no mater how god my hair loks curly it doesn't justify the burn I get from the curler! My hands covered  I suck at it!",
#  'Going to slep  Gona fal aslep playing aps again  Tmrw is going to suck',
#  '[<name>]  YEA     I GOTA BE UP AT 730',
#  'I hate when my bf beats da dogs  But I gues that the only way to teach these pits ',
#  'sprained my ankle  like realy badly and tore some stufs  it hurts! and its my birthday wekend',
#  "I can't believe the Metal Gear Solid song was stolen    I'm so disapointed  ",
#  'think i may have broke a toe at the bar tonight      thanks drunk girl for stepin al over me!',
#  'Not one sale done today at work  Explored balconies in the big theater w coworkers  A fun day, but void of chili fries and tips',
#  "[<name>]  I wish I had Left 4 Dead  But first I'd ned something to play it on   ",
#  '[<name>] me to',
#  '[<name>] that story reminds of living in Portugal',
#  '[<name>]  youre diabetic?   so is my dad   amp i might be to, not sure   are you stil alowed to eat sugar throughout the day?',
#  'I spiled my ber al over my leg  Wasted half my ber   Home now  I met a cute girl  God conversation ',
#  'my romate [<name>] loves to ignore me',
#  "[<name>]  I'l make him nachos tomorow  Beter than if he would have made them himself ",
#  '[<name>] yeah  ampdont judge my pilow',
#  "Scary lightning and thunder  I'm glad it's over now  Going to slep, I hope I'm not late to schol tomorow again  Haha",
#  'my teth and head hurts',
#  'I HATE rob zombie movies  amp the smel of wed  Vom ',
#  '[<name>] Maths and Science were the strongest for me i think  duno bout geography, only did like 1 day of study for 12 a year of work!',
#  'Waiting in line @ tryst',
#  "Hope I get a job cuz we ned an apartment  I'm drunk amp mis my lil punkin  TEHE!",
#  'just got home! not wanting to read the last chaper of breaking dawn cause i dont want it to beover',
#  'I ned to be held     Gnite ',
#  'Hanging out with sam, bily, and veronica  not going to schol tomorow to take sam to body shops  Dang car acidents',
#  'no more arested development  i am sad ',
#  '[<name>]  wicked , what time you leaving? how come you cant stay the night',
#  'omg i kep losing folowers this is so sad  i want 90 one day    thats my goal D',
#  'I fel so deflated  No more dogy ',
#  '[<name>] i wana se her hair  hows everyone?',
#  'I just had to empty my trash on the mac  that was one of THE MOST DIFICULT things I have ever done in my life  8,0 pictures are GONE ',
#  'im contacting PAWS Philipines so i can find quottigerquot a new owner  im so sad  i love my dog so much',
#  'just got home! not wanting to read the last chaper of breaking dawn cause i dont want it to be over',
#  'Aw     Pray for the aroyo family everyone!',
#  "[<name>] there's a manual proces    but it's taking 4ever on my outlok database    pf  crapy msft product",
#  'Fudge  Movie store is closed',
#  'ALO is so sad and quiet and empty tonight',
#  "[<name>] Hahahaha! It's not horible, if others were singing with I'm sure it could work  I wish I could aford my own drum set",
#  '[<name>] You never answered your DM I sent you       I ned your info   ',
#  'Am trying to get through the pilot of the first season of friday night lights  Oh gosh  Pas the tisue   ',
#  '[<name>] Aw where are you headed to? i just canceled my trip to Ausie',
#  'I have cystic lacrimal infectection? my eye and face are swolen and it hurts!',
#  "[<name>] I didn't think anyone caught that",
#  "I ned to be sleping   But i'm not even tired  ",
#  '0',
#  'OH NEVERMIND I THINK THIS THING IS UNSALVAGEABLE',
#  'lyin in bed, up far to early',
#  'Sad that Christian Lacroix had to file bankruptcy',
#  'I dont fel god AT AL  fuck',
#  'why did i agre to work a double shift',
#  "loks like i'l never go to the zo",
#  "[<name>] Oh por girl  I'l email her    I am relying on you being here in October Mr!",
#  'When wil Medhurst play again?',
#  '[<name>] bad times?',
#  'argh  Anger     a hose has leaked water al over the new floating flor',
#  'Have to go to the dreaded DMV tomorow',
#  "[<name>] I'm a bit Ben's Thaied out",
#  'english clas! working on interactive orals',
#  "[<name>] Thank you for the rec but that doesn't work",
#  "[<name>]  I'm sory  Excited for tomorow night? Karaoke! Geting anything special for bday?",
#  'My pupy Gizmo h8s me    haha  He stil growls @ me   I always lok back @ my long pruple scar on my fingie',
#  "I don't know how ima work out tomorow wit my body dis sore  ugh",
#  'in 71  wo you',
#  "[<name>] Yeah, plus it's just a litle to far to walk to Pinochio's for sushi",
#  "I'm feling this presure in my head that always kicks in just before a nasty headache  I'm not loking forward to this ",
#  "Taylor Swift and Joe Jonas loked realy god together  I'm kinda sad they broke up ",
#  "I'm supose to turn in a sentence outline for my research paper within the hour online but my neck hurts ",
#  'Lady acros the way had a miscariage, say a prayer',
#  'God I just want to slep ',
#  '[<name>] oh thunderstorms   bo  why do they always have to make the power go out?',
#  'I fel so deflated  No more dogy ',
#  'Found my bok  Starting a real paperbound journal tonight  Have an anoying zit above my lip  Makes me lok like I have herpes',
#  "RAT ROCKED NASHVILE TONITE  ONE THING SUCKED, NO ENCORE!  LIKE IN THE 80'S THEY STIL HAVE A FUN SHOW  PEARCY HAS THAT HOT BAD BOY LOK",
#  'is feling bad  just got bad news about my Mum',
#  '[<name>] But but I dun wana',
#  "[<name>] damn girl I'm so down but ya gota let me know so I can get my kit together amp I got a flyer  Any next wekend? IquotM DOWN!",
#  '[<name>] dbl bo for being sick, flipin blows!     bahaha i kno i dont have many friends on here either  i fel so lame  haha',
#  "[<name>] thats what i was thinking but the only time it's gona be on is 1 am!",
#  'Peps stil here  Fun times  Gota slep tho  Work in the A M  Some col, hot chicks here  But none as col as   Mising her',
#  "don't fel like working  I think I twet this to often!",
#  'fels sick to my stomach and idk why',
#  'vineri   nimic special sau probabil un alt wekend pierdut   ',
#  'Counting the hours of lost sunshine until the Wekend',
#  "[<name>]  dude i just saw your SF pics  loks like your mini excursion was prety kick as! didn't se any sun while i was there tho",
#  'is home   safely    but hungry',
#  '[<name>] Um, I was thrown from [<name>] van yesterday and had to be taken to the ER',
#  "got to final table, but    went out third   Don't think I'l be geting my fre seat",
#  'god morning work this morning guted lol nevermind',
#  'I have to work in the morning while my friends get to party it up     stupid bery lite flashing red and I have no mesages!',
#  'FB is boring   and i wana sing RIGHT NOW  ! ',
#  "[<name>]  The link doesn't work",
#  "[<name>] hahaha I don't know anyone or anything about it except they have powers lol    I live in my own buble",
#  'The humpalow um ya I think so    Cel is dying',
#  'Last day at work   Sick to the bone',
#  "i fel like I'm on house arest ",
#  'love is like a war,easy to begin, hard to end  fiuh   ',
#  '[<name>] ur suposed to be in BK tho',
#  '[<name>] Did you know that there is a shortage of shels for crabs to use on the beach due to beach combers? It is very sad',
#  'Oh no!  Nighty night ',
#  "[<name>] Must    have    new music    I won't slep until you give us Chapter 1    I might die first though     Hury!",
#  'my stupid toth hurts',
#  "[<name>] love the song quottogetherquot  that's quothisquot song for me   wel i think it's stil is",
#  'Ready To Go @ Schol',
#  '[<name>] my computers broken and I broke my laptop so I had to use the phone  ah stil on he cause they fucked up my order ',
#  "[<name>] It's god isn't it! Our holiday chalet is out of sight but lok v similar to those ones  Going home again today",
#  "It's a sad economy  Just heard of another friend losing their job   so sad  But just a reminder that   ",
#  "[<name>] I'm just starting to fel realy panicky and anxious that something bad has hapened cos it sems like it's ben ages",
#  'my dog ran away',
#  '[<name>] Those suck so bad ',
#  "I'm back  top molar extracted  swolen face, al numb   But no more tothache or sinus pain ",
#  'just finished 8 hours of Texas Life Insurance CE tonight, 2 more hours to go',
#  'does anyone know any god rap songs? i ned to make a rapfun cd and i have no idea  help',
#  'I want to go to Peru this sumer ah! Hopefuly! Yesyesyes! I mis it over there!',
#  '[<name>] what hapen to the maids of yours? Quit once again?    ',
#  "I'm awake  Anybody else awake? Wish I lived in the US since al the fun hapens when I'm aslep!",
#  "At Charle's with the power out  LOL! Damn SaveMart lost power and we could not buy ber ",
#  '[<name>] hehe  i love you! i am tired ',
#  'my mobile phone refuses to charge!  either the batery is broken or the charger  bo',
#  '[<name>] oh how i wish you would get her to sign something then send it to me or let me cal you when you met or something',
#  "[<name>] hm, I thought u were sleping! To bad I can't se those videos until tomorow night ",
#  'Morning everyone sory for going early last night had bad news, felt totaly crap   Today is a new day',
#  'went to the beach and it started raining',
#  "how I wish my parents put me into a Chinese schol when I was younger  Then, it'l be so much easier for me to get a job   ",
#  "[<name>] [<name>] Yeah, physicaly moving to!  Aparently we'l be reporting directly to Mr  Hayward   ",
#  '[<name>] airport? and you didnt show up tonight homo!',
#  "[<name>] jealous  it loks like schindler's list in toronto",
#  'I want another tat',
#  '[<name>] what?! Come as you are! But erock just left  bah D',
#  'So, I ned to make a lot of money tomorow',
#  '[<name>]  being in your rom makes me sad ',
#  "Nearly fel aslep, but was jolted out of bed by a masive panic atack and now I'm not sure if I can slep at al ",
#  'for the gays i only made 20 tonight',
#  '[<name>] oh Anger! I completely forgot about Thirsty Thursday! oh  my  gaga  this sucks',
#  'if one people did any wrong, the world blames al the people over there, this is the great world which we are living in!  Shit!',
#  '[<name>] nope   they are al sleping cuz they live on the east coast ',
#  "[<name>] I bet its col down in SR, huh? It's not here  I haven't stoped sweating since non when dad and I were packing",
#  '[<name>] ew  dislike',
#  "Tactical mistake going to the city library and buying milk  Who knew? OUCH  Maybe a god thing I didn't try for uni ",
#  'decided 2 trans frm relaxed 2 natural hair but i wish my whole head loked like my rots   Age of the instant gratification    ',
#  '[<name>] sory bout the cat,',
#  'neds to have an increase on her salary  ',
#  "my stomach fels like it's touching the ground  i'm SO ful",
#  'Pug just woke me from an incredible slep!',
#  '[<name>] i cant wait to hear your new album  im sure wil be amazing please just replay to me  i love you so much!',
#  'So much work so litle time',
#  'mised iron chef',
#  '[<name>] the DS version sucks',
#  'what a bad day',
#  '[<name>] i know ridiculous! we never got to hang out  i love chicago and want to go shoping    so a trip sounds like fun',
#  'hates the net  ayaw bumukas ng twiter   ',
#  'Ugh, my internet was down!',
#  'omg i didnt twet al that much today     sadnes',
#  'is feling so gidy and wana go home ',
#  'the wek just wasnt the same without an adam lambert performance!',
#  "[<name>] The link doesn't work",
#  'Up and packing  Its the last day of youth camp',
#  'GOSIP GIRL, WHEN ARE YOU COMING BACK  ! chace  ',
#  'Smh @ hiphop nursery rhymes',
#  'Somebody please save the polar bears!',
#  '[<name>] no i just lok at a lot of pictures   lol',
#  '[<name>] Not realy slepy    bored is the right word     again not much work',
#  "It has come to my atention from a 16yo friend that I've recently gained a TON of weight  He didn't know it was me ",
#  'gues im staying home tonight   no movieing for me',
#  'went to the cd store to search for the cd  But',
#  '[<name>] reminds me of the weather a month ago it was horible  I hope al is wel hugs',
#  'I mis my mom    quotMay angels lead you inquot',
#  "there's realy no android twiter ap of Twetie's calibre",
#  "on jacksonvile beach walking in the cold As water   but have to work in the morning   ily lt''gt",
#  "[<name>] No, it's not   ",
#  '[<name>] i fel the same way every day',
#  "Can't slep  Sucks  The one day i have to slep in and i have to get up and go shoping with mom  Ugh ",
#  '[<name>] wel i just got home and its not on til tmw at 530p but with comcast its on right now  but i didnt mis it',
#  'Slepytime  Realy mising my godfather right now  Love you Wayne',
#  'So have a headache right now and it sucks',
#  '[<name>] hope ya slepin wel  guys stil here',
#  "i should be finished     but i'm not   color drawing, here i come ",
#  "[<name>] Lakers, baby Lakers! I'l mis the game tmwr  I have to work  you'l have to kep me posted please",
#  'comfort fod of the day pan me  though, it didnt taste any god  ',
#  'damn being drunk and hot sucks',
#  'mises my baby ',
#  'is not sleping because he has paperwork to do ',
#  "Showered in icecold water  Sweating now  Means one thing I'm sick",
#  'midnight cry   wish the person I wanted me right now',
#  "[<name>] I'ma ned you to folow me real quick cause I can't DM you",
#  "I'm porly and can't slep",
#  'Went to pole clas  Feling discouraged  I am hopeles when it cones to dancing or sexy moves or spreading my legs ',
#  "[<name>] And these por, unfortunate souls don't apear to have any pants at al     ? ",
#  '[<name>] [<name>] If I told you how often I wash my hair you would never speak to me again',
#  'Loks like another sleples night dedicated to homework  Sory in advance, Ms  Chapman ',
#  '[<name>]    WHY DO U LOT MOCK ME!',
#  'didnt say godnight to you',
#  '[<name>]  I am not a pusy! damnit!  sending you an email right now btw',
#  'has work tom ',
#  'In the Hongkong International Airport  Has to wait for 34 hours for our next flight to Cebu ',
#  "Can't slep and nothings on tv!",
#  'The pics I just uploaded are the baby pics of my cats  Misy is now an adult and a prety litle kity, but Baty is in kiten heaven now',
#  "[<name>] oh     you've ben superseded?  not god enough",
#  "today we say godbye to the second god friend in a wek from dmp  but at least the sun is shining and I'm definately NOT working this pm",
#  "fuckin'm transtelecom",
#  'is realy bored    I gues I wil go to bed',
#  '[<name>] I met a stranger just 10 min ago  He was stalking me at the store',
#  '[<name>]  te we befin    what was u suposed to do before leavin?',
#  'Sometimes the things you say hurt the ones you love most unintentionaly   And you can never ever take it back or fix it ',
#  '[<name>] that sucks!',
#  '[<name>] I know! and mean',
#  'Having Fever  dont fel to work',
#  'Taking Horse Pils, hoping I can get some slep tonight',
#  '[<name>] PGPM student from where? I myself was a PGPM student about 4 years back  I wish I could stay one',
#  "mising [<name>]   6 days can't pas quick enough",
#  "[<name>] Hey! That's my schol! I hate that place ",
#  'Working from home today, my back is kiling me  Doctor and then physio after later today ',
#  'back to work   with no distractions  ',
#  '[<name>] demi, just say hi to me and its enough  just replay to me please  love you so much!',
#  'a  i never noticed this ',
#  '[<name>] that sucks  wel state starts tomorow so im headin 2 bed, nitey nite',
#  "Loks like it's going to be to nice to work today, how anoying as I have no choice",
#  '[<name>] did you guys kep a set list? I forgot to ask for one  x',
#  "First impresion of Silverlight sadly, based on what I saw today, it's quite problematic",
#  "is desperatly hoping my dad takes me to vanesa's game",
#  '[<name>] hi!  Fuck your job!',
#  'Mising you al deply',
#  'the time you go to bed,  i have to get up to go to work',
#  '[<name>] big now! Vanesa is going to be 3 in September, its going by so fast!  its hard cuz Im workin so much, I mis out on alot',
#  "[<name>] snif  take care ravels! Hopefuly we'l be chating again son  In the mean time, I'l HELA mis you ",
#  '[<name>] Lucky, now I want to teleport',
#  'Somebody please save the polar bears!',
#  'My nose is runy, my head is pounding, and teth hurt like a bitch  MAN  @ I fel awful   ',
#  "I don't want her to leave  ",
#  'Headin home   Refreshed my mind and soul justa lil bit   Bac to reality ',
#  'god lord, just sen the agency work for our upcoming Open Day  Money for Jam',
#  'wut do i do now?',
#  "Working   But it's Friday",
#  "At the Grove for 'Drag Me to Hel ' I hope that it doesn't suck ",
#  "[<name>] so i fel like shit for saying HAPY BELATED BIRFDAY   i'm only a month late",
#  "[<name>] lmao   thats sad, kinda discourages me 4rom goin if the shit's wack",
#  "Got home from work @ 945 and JUST finished cleaning  Now I ned to eat diner and don't know what I want!  Ugh   oh wel  Might not eat ",
#  '[<name>] I wish I was there',
#  'I mis my litle Baty, she was only 3 months old when she got sick, she was always so fun and ful of life lt3 Even at the very end   ',
#  "FC is finaly up again  it's about time  i hate that this keps hapening",
#  'seriously bored without anyone to talk to    but not tired enough for slep',
#  'morning again! I hate mornings  So ofensive!',
#  '[<name>] stil! give your computer a break omg',
#  'bed [<name>] do you never answer texts anymore?  I thought of you the other day and sent one but never heard back  Sad day',
#  'where u at?',
#  "[<name>] wah  We're no longer your peps ",
#  "[<name>] LOL wow dawg doesn't sound like you're playing!  I fel bad now haha",
#  'Extremly dep',
#  'My litle foster kitens are geting big   chuba and Winston are going 2 b mised when they get amazing homes ',
#  'one wek til exam block',
#  "[<name>] I'm not at home with my cats right now!",
#  "hoping i didn't fail english  that would just be sad",
#  'Know what would be great? For my shoulder to stop hurting so I can slep normal again   I just wantned a few solid hours of god slep ',
#  "Leno's last show was tonight   I like him beter than Conan ",
#  "[<name>] I'm sory about your bad driving experiences ",
#  "[<name>] i don't have any of that",
#  'Already mises [<name>]',
#  'plan may changes , no',
#  'my sister is a douchebag',
#  "[<name>] there's relisting fes when you don't complete a sale?  that sucks!",
#  '[<name>] Random has an a',
#  "I knew I should've worn the SARS mask on the plane from SoCal   feling the beginings of a sore throat",
#  "Guted that the bathrom stil isn't fre early work isn't going to hapen    And I ned the lo!",
#  '[<name>] july    to long',
#  "[<name>] aw I wish I could have ben there  I'm stuck here about to jab out my eyes with kniting nedles",
#  '[<name>] Me to   Wonder if Mnet wil show it   ',
#  'Wearing glases gives me a headache ',
#  '[<name>] stop talkin about fod haha fil like sum nw  ha hows your day goin or starting',
#  'finished sewing for the night, uploading pictures from slidebar and beach  i cant believe i am having dificulties with twiter!',
#  'thank you [<name>]  cant wait! um btw ima crash stil sick',
#  'First my work computer, now my home laptop is fucked ',
#  "liesgirlstel  a guy cals her phone to se if the number is real  oh my phone isn't working   try tomorow  ",
#  'ber friday melbourne cbd mtub mini cmon Thirsty and lonely     you bugers are making me fel like a scoty no mates',
#  '[<name>] I know  We came back from 2 down in the 1st just to lose the lead in the last 6 minutes ',
#  'gosh    sumer vacation is almost over here at the philipines   kinda sad    i wonder what section wil i be in?',
#  '[<name>] But [<name>] is on page 6 at Ms Twiterworld, only 26 votes',
#  "I'm bumed that I can't wear my swet Nike kicks to work ",
#  '[<name>]  your twiter is broken',
#  'slep    god night tweties! down to OC tomorow  I hope and pray that Rachyl gets beter SON!',
#  "[<name>] It's depresing I'm stuck inside al day",
#  "[<name>] I even saw the news feds of the archie website  But can't believe he'd chose veronica  I'm disapointed",
#  'i hate being sick  i mis [<name>] [<name>] and [<name>]',
#  '[<name>] im eating sliders at barjohnys! theyre pork tho not bef  stil on the search   ',
#  'Geting ready for schol  second maths test today  also its my last day of 3rd year! Next wek i wil oficialy be in 4th year',
#  'Woke Up,I Wana Stay In My bed',
#  "depresed that i wasn't included in the morcom gardens quiz on facebok",
#  '[<name>] yeah, its stil totaly in the high 60s here  so notloking forward to aug and sept up here',
#  'Upsidedown tomato plants died!',
#  'So dep its priecing my soul',
#  '[<name>] Oh come on! You get next wek of and I get next wek ful of exams!',
#  'friday here at last, not much fun when your skint though',
#  "[<name>] i know, don't tel anyone  i dont know if my dad told the famz yet  i think i'm taking it online ",
#  "[<name>] Can't Iht Be Earlier? ICant Wait That Long   Ahar  ",
#  "Friday yay! And a bonus, don't have to drive to Wales tonight   Athough wil mis kiten cudles and going for a ride",
#  "My children have promised me birthday brekie in bed  There's a problem with that in that there's buger al fod in the house",
#  '[<name>] wops! I only just realized my DMs to you are not going through',
#  "I don't think I wil be able to get out of bed tomorow morning  we wil se!",
#  'I cant use my blackbery today  This sucks ',
#  "Q what studio created 'Open Season'? should gogle it or lok at the dvd downstairs but feling lazy",
#  'the times they are a changing',
#  '[<name>] why do you hate me!?',
#  'time for tv in bed Then spending al day catching up on studying  i hate online sumer clases',
#  '[<name>] video is not available to us foreigners',
#  '  Wanted to visit the animals but we were to late',
#  '[<name>] PC I agre     We have a problem  We must stop spending and only work!',
#  'jonaswebcast i just mised it!',
#  'Dang it! I REALY lok like crap! Sigh only had 35mins to shower and 10mins to get ready',
#  'waiting to get picked up!',
#  "So exhausted  can't slep  I don't like these nights",
#  "i'm gona mis al the live Comet action tomorow! i have to go take care of my cousins and they don't have aces to the interwebz",
#  'lol i cant drink!',
#  "if bil compton has wi, why can't he have twiter?",
#  '[<name>] sory to hear that ',
#  "Morning Sports day today, and I have to do the threleged race with [<name>]   Mr Petigrew said I'm not aloud to trip her up",
#  "Just found out I can't drink at this bar! Bo mising e1 at palomino's! No chers sad face",
#  'Canot slep  2 hours of tosing and turning ',
#  'Omg going to die of swine flu when I go to Melbourne',
#  "Packing  I don't like it  ",
#  '[<name>]   dang it, so its not certain ? ? ? are you okay?',
#  'wishes Dave Gilmour and Roger Waters would reunite for a Pink Floyd concert',
#  'finished a whole box of ice cream',
#  'In 1 horse town  2 blown out car speakers ',
#  'Someone make me a cofe      ',
#  "[<name>] plus I just deposited tax return cheque but for first time in 7 years it didn't clear imediately",
#  'Photo martwo OMG i love you! i acadentaly deleted this photo  yay hes SO beautiful ',
#  '[<name>] I know  amp my hot water botle is in whangamata without me  ah',
#  'My nose is stufy',
#  'last night in newport',
#  '[<name>] thanks for the rt and sory about your new place with the domestics',
#  'Ok, other then my shoe, the club is col  Its fun, and its popin except 4 the pl tryna dance wit me',
#  "Holy crap! It's raining in LA and I don't have a jacket!  oh no ",
#  'Aright Twiter Fam    gues ima be outies   gona try n slep of some of this horible pain',
#  'Baby was not herself after recieving vacines',
#  'Wish I could atend E3 this year  But these smal events like the NBA and Stanley Cup Finals kep geting in the way    Work, work ',
#  '[<name>] lol hi emy, latin would help me study for the aptitude tests to get into grad schol  thats why i wana take it',
#  '[<name>] btw I am not a wimp',
#  '[<name>] LOL yeah you big perv  Was hoping to se you next wek but scraped plans',
#  'Rejecting al fod substances ',
#  '[<name>] no I was trying to interview Dr Paul Twomey, CEO of ICAN  Phone isues cut the interview from 30 mins to 15 ',
#  "[<name>] i can't ad you on myspace girly  it asks for a last name and email",
#  "back at Viena   , so tired, lugage lost, Manchester 'd ben great  very god outcome from Seminar at MBS amp great people around    ",
#  "[<name>] don't think i can take a nedle  watched a horibly gory short film on drugs a few months ago  i'm scared for life ",
#  "I don't wana go back to work   slepy time ",
#  '[<name>] It fels not god ',
#  'watching The Bigest Loser on Halmark  Never fails to make me cry  nyeh ',
#  '[<name>] that sucks!  how old are you actualy?',
#  'Thinking about geting up for work',
#  'Stil confuse   ',
#  'I was a very naughty girl tonight  disapointed with myself',
#  "[<name>] That's beter than Misy 8 teling me I should be on The Bigest Loser",
#  "  NO! he goes for Orlando! OMG  I'm gona CRY!",
#  '[<name>]  AH !  SO SWET !  I mis that age       SO MUCH !',
#  'Just saw a fox!  as i was geting on the freway    I hope it goes home',
#  'scratch that slep on a stage bound ',
#  'recaping on britains got talent  britain sems more talented than america',
#  '[<name>] I cnt get it! its goin to ur old mesages?!?  gtgtgtgt HELP?ltltltlt',
#  'god time Rocking out @ open mic, thanks 4 al the love n suport  Now working on Busines plan presentation  No CG again 2nite',
#  '[<name>] Swiming is a no go for me',
# ...
#  'big day 2day the xt launch was amazing! so much fre stuf thanx 2 the edge and telecom! found the phone i want   cnt aford it yet tho',
#  "[<name>] Oh yeah, i'm the porest person of al  But i shouldnt joke about that, por other people",
#  'I just realized I speled quotadorablequot wrong when I tweted [<name>] she must hate me now',
#  "[<name>] But now it's gone",
#  '[<name>] oh  wel i hope she gets beter',
#  '[<name>] who are the crew? please dont be me     i dont think it is but i could be wrong i have ben a number of times   ',
#  'how to have a glowing face? my complexion is always so pale',
#  "Downloadfestival's lineup isn't as god as i thought it was  There are some other awesome bands doing the festivals, but mising DL",
#  "haven't watched gosip girl in ages ! and ned one tre hil season 3   god i'm so slow",
#  "[<name>] You're cycling tho' that's god  Healthy eating  Healthy and eating are a contradiction in terms ",
#  "So     I'm kinda o sick n tired of the bs that guys dish out  !",
#  "[<name>] I hate you , Fletwod is my favorite band   I'm so jealous  ok I stil love you haha",
#  'So wish the Carlton game was on live  stupid chanel 7 lol ',
#  "Up early again tomorow    heading to bed now  I kep saying I'm going to take a miday nap, but it hasn't hapened this wek yet   ",
#  'ups ketauan cabut sama [<name>] [<name>] nih',
#  "says morning everyone, of to work in 10 min's  ",
#  'i no i no bt i had only ben a gamer for like 2 years when i made that atempt  lol yea i luvd F1 to an extent [<name>]',
#  "It's 4pm Friday, he left at 6am Thursday     surely he should be there now",
#  "[<name>]  I'm so sory    ya gota let me know! I've ben boked al wek!",
#  '[<name>] hahaha oh man please come to pomona i would love to se you everyday instead of like once a year if that',
#  "[<name>] I mis you!  Come to Michigan like now    I can't wait til July",
#  "[<name>]  maybe a god night's slep for everyone?",
#  'far   pdhpe asignment due next wek and have english homework !',
#  'forgot his aces card in the carto lazy to fetch it',
#  "[<name>] Yea, its tough to kep it going  Sometimes I'm not sure its worth it ",
#  '[<name>] such a disapointment  haha',
#  '[<name>] hun are you okay? I se alot of your posts your exercising like mad,not eating or sleping',
#  'oh no my twetdeck is malfunctioning O il have web wil its fixd',
#  "[<name>]    i'm sory about you are stil sick  u know most of them, AND i know that u wil gues the quotpelzer presentquot ",
#  '[<name>] Adam Samberg  new mon trailor  god evening  To bad my cable is of as of friday',
#  "[<name>] What hapened? I'm afraid I mised a large part of the story",
#  'Work at 545am ',
#  "[<name>] Hel yes  I'm to late ",
#  'Del FX10 PcoverIP audio device Teradici is giving me a hard time in Linux Ubuntu Jaunty  Kernel isnt loading the sndhdaintel drv',
#  'Just got my as kicked in Tripoly lol  I got such bad cards    i suck',
#  'creped it up at the ice cream social! god times  lars and the real girl, such a sad movie',
#  'so     Hot in here huf     ',
#  'closenes or distance? closenes    but now everything sems so distant   ',
#  'And another one bites the dust',
#  'Ah! My quotLet The Right One Inquot DVD broke',
#  '[<name>] hey i loved ACS but i had to se it online, is not here yet   cant wait to buy it! you lok amazing there',
#  '[<name>]  my thoughts dwel on a certain person',
#  'fml my work uniform is on the washing line',
#  'oh shit i just realized she stil not talking to me  it b like dat some times  ',
#  'on my 42nd writen fuck   i get les ideas every day, and every day',
#  '[<name>] naw, it doesnt match up LOL and i have no shenanigans to discus     but i did do the thing   ',
#  '[<name>] not this part, unfortunately ',
#  "[<name>] dude, i didn't know it was a personal experience  sory something like that went down",
#  "[<name>] aw wel I just randomly woke up and now I can't slep! To many things on my mind",
#  '[<name>] me to baby    Mis you',
#  '[<name>] Since obviously living in Alaska, only a few radio stations we get here ',
#  'i just murdered two fucking mouses! now i cant slep',
#  "Oh noes   hey, what's my tato say?",
#  "[<name>] I don't have a VCR   ",
#  '[<name>] I wish I could have time for my xbox  project al tied',
#  'al my pancakes always end up sogy ',
#  '4 very big ?zongzi for lunch, ate more, but not work more Work les but eat more, what  can I do wh it? To useles become ',
#  'sososo bumed, like realy bumed, i hate this rain, ruin my date   ',
#  "Working late at night on a Del notebok, Del's quality has gone down hil, warenty service sucks to, por people  buy a Mac instead",
#  'Wow  That hurt way worse than i thought it would ',
#  "Why do none of my thoughts make sense when I'm sober?",
#  '[<name>] I know right  but hopefuly something comes up though',
#  'I cant to slep and tomorow i must wake up to early',
#  "[<name>] As it is now, my body has already developed a mind of it's own but that mind refuses to cooperate with set schedules",
#  '[<name>] suposed to be back Sun via private jet btw!o but mite hav to stay bymyself thnk god for another wek  amp want Bruno!',
#  'And trash repops   Geting it tomorow night I supose ',
#  'Nursing bruises from motorbike crash on Wednesday night leaving London workplace  The ground is so much harder the older you get',
#  'so bored, i have a headache ',
#  'Huge headache   godnight!',
#  'fels like crap whenever she lays down  [<name>] I hate heartburn amp backaches!',
#  "[<name>] I mis you! It's lonely and empty without you!  ",
#  '[<name>] NOICE  I realised that after exams I have 2 more weks  Forgot about the whole 2 weks of Unit 4 in term 2 thing ',
#  'I justwatched like, 5 straight episodes of escaped on ID Discovery chanel  A guy imprisoned 6 women, kiled 2 and coked them',
#  'Mising Everyone',
#  'Should have gone to bed ages ago, damn you tedtalks!  Gota get up early to',
#  'its only 0 2! Just give me my 3 points!',
#  "[<name>] make the most of pork products while you can, they've fucking stoped importing it here in dubai  bad times",
#  'another build failed! something is not right in the big scheme of things!',
#  'My wife tok my last 20, no McDonalds breakfast for me today',
#  'I wish I was going to we love sounds',
#  "My siser is moving tomorow and of makes me sad  actualy I gues technicaly in a couple of hours since it's already Friday ",
#  "I kep on faling aslep when I'm supose to be awake  I mis my baby  ",
#  '[<name>] why not?',
#  "On my way to notingham  I so don't want to be going",
#  'No churchil downs for me tomorow',
#  "to Chicago    but why isn't my ride caling me back?",
#  'K, godnight! Gota do Chuck E Chese tomorow folowing kindergarten shots and physical    Bla',
#  "I ned to wake up earlier so I'm actualy tired enough to fal aslep",
#  'Bah the police ended the party @ 5!  Just when i was starting    ',
#  "I've got to catch the bus to work",
#  '[<name>] that is so sad',
#  "[<name>] omg you've never sen 'the Ring' its a crepy as movie",
#  'man      [<name>] got an iphone! im jealous    ',
#  '[<name>] funy u havent showed me any love yet at al',
#  '[<name>] absolutely nothin',
#  '[<name>] I luv urs! admiting niley with a kis  but then they change their minds  haha amp demisterling  not jemi but stil cute',
#  '[<name>] If it makes you fel beter I lost 10 overnight cause I posted a picture of a baby',
#  'is stil sick  sigh',
#  "[<name>] Oh por beths friend  i'm not naughty, i'm just unperfect ",
#  'Josh just caled me a big bucket of ugly  wish me luck for my audition twets!',
#  'i fel realy weird',
#  "[<name>] I'm trying to self learn photoshop but it's not going so wel!",
#  "[<name>] Ever sen the tv show Dead Like Me? I died and became a grim reaper  Taking people's souls after acidents",
#  "[<name>] I'm sory  I'm thinking about you and hope the wek gets beter!",
#  "Steam Punlk fashion show at Anime North and for the first year since TorCon we aren't back til [<name>] amp mised it",
#  'my throat hurts  gona go read and go to bed  text me!',
#  'I am dying to hangout on a Friday afternon   ',
#  "Eh   it's cold",
#  'man      [<name>] got an iphone! im jealous      ',
#  'fjdskal im realy frustrated ',
#  "[<name>] Aw, you should've YouTubed it ",
#  'Wondering how come mcdonalds take so long to deliver my fod ',
#  "[<name>] Ya, the weather has ben super weird here  It loked like it was gona rain today but of course it didn't, darnit,",
#  '[<name>]     much more injustice than we can imagine now  It wil get worse before it gets beter, I am afraid  No doubt here  Sory',
#  'Wil mis nostalgia     everyone please kick tushar',
#  "So     I'm kind of sick n tired of the bs that guys dish out  !",
#  "clas color day tomorow! last time!  I have a lot to remember for tomorow but I bet I'l forget ",
#  '[<name>] idk lol my head hurts  rly bad  amp so does my stomach    hm    personaly, i think its from al the s ive had 2 deal wit',
#  '[<name>] [<name>] BUT THEY ARE EXPENSIVE ',
#  'WTF facebok just cleared out my whole survey and i was on the last q, this night gets beter and beter  what else is next?',
#  'says god or should i say bad? afternon!  ',
#  "says I've got number 10  geting low ",
#  'Mises his twitastic fwiends',
#  '[<name>] take my advice lokin through the phone cost me my relationship',
#  'was playing stret fighter IV and Seth Raped me',
#  "Its weird being at the guy's house without them here  I don't like it",
#  'FUCK wasting deodorant    i aint goin no where    i aint havin company  let me funk it to ya!',
#  '[<name>] I wish I knew!  The curse of Tumblr ',
#  "what a beautiful day  shame I've got to spend it in an ofice",
#  "I came with a q quotany recomended hairdreser? U r ful and they sugested me to others  quot His ego talked and I'm in d line",
#  'Busines exam tomorow',
#  '[<name>] oh, i know how budgeting is ',
#  'Just finished watching the series return of the Chasers War on Everything  realy quite crap compared to how it used to be',
#  "Wow just realized haven't checked Twiter since 9am when I saw my todo list  God news got lot done  Bad newsdon't know where day went",
#  "  mis my bestfriend ' now she left schol",
#  'OUCH! my earphones just shocked me',
#  "[<name>] I'm trying to slep! It's not working",
#  'Tumy hurts',
#  'back from grimsby  it sucks bein back but was amazin wknd anyway!',
#  'fareweling an employe tonight   ',
#  '[<name>] haha, its under 18 @ so ive got no one to go with  curse none of my friends liking TAI lol',
#  'Gorgeous weather, but no bike',
#  "Morning al  The water heating's packed up, so i can't have a bath  I REALY want a bath!",
#  '[<name>] Girls are confusing ',
#  '@ lyricalyMe   Why would you do that to me?!',
#  "[<name>] se   u shouldn't be comin' 4 the city, u should be comin' 4 me",
#  'Blackout in the city is never god',
#  '[<name>] Aw maybe i traumatized her ',
#  "[<name>]   Flights already boked, plus its GD2 1st birthday  Can't mis that ! especialy as we mised GD1",
#  '[<name>]  Where I live, al the smal markets deliver their dayold bread to the fod bank, but times are realy tough, even for me',
#  "I have drunk hickups  I had a prety laid back, great night  But I stil can't help but be mad about the situation I put myself in",
#  'why do i think i have to take medicine cuz i was laughing to hard?  my head should not be in this much pain  i thought laughter was gud',
#  'Ugh  To much hapened today  I realy ned a hug',
#  'boring  i wana go for taekwando',
#  'Watching Leno for the second to last time on the Tonight Show',
#  '[<name>] Ur pic is gone',
#  'My tongue stil hurts   I ned to slep!',
#  'how do you twiter?',
#  '[<name>] Chris and I are staying in Glasgow instead cause there is absolutely no acomodation in Edinburgh due to the marathon',
#  "I can't wait til it's Sunday, a new episode of Supernatural but then there are only 6 episodes left now",
#  '[<name>] aw  ok lol hopefuly by than im stil here and not back over in the states',
#  '[<name>] Sad twets are sad',
#  'neds a litle lie down  not feling great today  bo',
#  '[<name>] not at my workplace    but a shortsleved shirt is absolutely necesary today!',
#  "Have decided I just can't stand [<name>] Altop spam any longer ",
#  'its from al that anal sex, i forgot the lube  damn  may ned to go to the E R ',
#  'Playn maden with austin  Im going to mis him  ',
#  'i mis rich',
#  'Headache of the century coming I can fel it  Fuck ',
#  'disapointed to know that I got the Silver Award  I want the GOLD award  I hate being second best ',
#  'PLEASE MAKE THE LIVECHAT ON SATURDAY CUS I HAVE TO GO TO SCHOL ON WEKDAYS56 AM here   [<name>]',
#  'I want to go back to bed but have a child to lok after!  I may slep al of sunday, my enevitable hangover may require it!',
#  'I just got mad tired so no sex  slepytime night!',
#  "THIS TWITER SHIT BORES ME, NOW I C Y I HAVEN'T BEN ON HERE IN A MONTH",
#  'does anyone know how to convert 6 est to Aus time? ROFL xD fucking radio disney',
#  'home from ice cream twetup my very first twetup! No pics because my camera batery died last night and i forgot to charge it',
#  "[<name>] ok that's subtly saying i'm no longer a fave  teme 1 thing  did the firangs steal your vocab? ur eating words and how!",
#  "[<name>] bye, Scoty!  i'm gona mis you  ilylt3",
#  'New Coment On Jowki  I wish I had the time to blog more often  ',
#  'we can get a temporary tato  I would be totaly sad if he died ',
#  '[<name>] gray!      i so fel neglected',
#  '[<name>] oh so you know how I fel then  Damn representative for bank of america tried to make it sound like I did it  What a b    ',
#  'is tired and cold and runy',
#  '[<name>] Dun wana travel al the way there for lunch now  But yeah i have ben there  Nice place  Mising ShanePunjab though   ',
#  'Doing a mas cleanout of my rom before rearanging it  Just sent mother out to buy me a bin and a bokshelf since mine sucks  Bad mod',
#  '[<name>] rob got lucky that game he beat me 209205',
#  'feling realy sick  watching the fifth element, and about to smoke a cig  ugh i hate colds!',
#  "Bah I don't think [<name>] FB fan page wil get to 750",
#  'someone save me! i dont want to pack anymore',
#  'home from schol had the shitest day today',
#  "[<name>] The swety sat on the table this morning   Just woke up! Very swet! Oh   btw   I think i'l be home around 7 pm!  Xx",
#  'bruise on kne wil make it hard to skate tomorow ',
#  '[<name>] lol   When I went to buy my new laptop in Feb , I already knew, lol, but I loked anyway and walked away sadfaced  ',
#  'FYI no internets until THURSTAG! after saturday  i have a feling i wil become 80x more productive during those days ',
#  'Siting by myself  Everyone tok the god seats ',
#  'NO FRE WIFI!?!? My vacay is ruined!',
#  "[<name>] Ah  Wel at least I'm up to!",
#  '[<name>] Mat Havent spoken to you in ages dude  Dont forget bout ur Ausie fan   lol  Love ya x',
#  '[<name>] ME! oh wait wrong state',
#  "It's fucking cold here north now! It was like 7 DF yesterday where I was, here it's 37,4",
#  'Are u mising ur frnds ? Hear to quotManaselam quot From Kulir10 Degre movie  Its amazing !  Nanbargale  Mis u guys !',
#  "Trying to slep without any pils    Not working  3am and wide awake  But now it's to late to take them because I'l slep til 3pm",
#  'Phone wil die son  What to do now? Oh no!',
#  'Sory was that mean',
#  'Forgot my power cable at home today',
#  'Dogs eyes sem bad  Just forked out on new washing machine so why not a vets bil to top it of eh?!?!',
#  "I can't slep  I can't find my grandmother's quilt or locket  I'm sick at myself cause I may have lost them somehow  Or they were stolen",
#  '[<name>] I thought I was going to se a pic of your clean car',
#  "[<name>] i want to! but im not over 18 and tampc says over 18's only  wana make an exception for me ",
#  '[<name>] No, but it does amazing things with keping al your online conversations in one place    unfortunately that place is Gogle',
#  '[<name>] sory, is only in spanish for the moment',
#  '[<name>] Yay! but thats sp far away!',
#  'must clear out my DVR    geting rid of it tomorw ',
#  'Bumed that F! broke up',
#  "I signed up for an acount on a political website so I could post a coment but it isn't working ",
#  'How Come I Can Never Slep Past? Not God',
#  ...]

# %%
# for lemmatization,tokenization and extra preprocessing
from utils import process_tweet
lii = [process_tweet(x) for x in li]
lii
# Out:
# [['<name>',
#   'know',
#   'listenin',
#   'bad',
#   'habit',
#   'earlier',
#   'start',
#   'freakin',
#   'part'],
#  ['layin', 'n', 'bed', 'headache', 'ugh', 'waitin', 'cal'],
#  ['funeral', 'ceremony', 'glomy', 'friday'],
#  ['want', 'hang', 'friend', 'son'],
#  ['<name>', 'want', 'trade', 'someone', 'houston', 'ticket', 'one', 'wil'],
#  ['repinging', '<name>', 'go', 'prom', 'bc', 'bf', 'like', 'friend'],
#  ['slep',
#   'im',
#   'think',
#   'old',
#   'friend',
#   'want',
#   "he's",
#   'maried',
#   'damn',
#   'amp',
#   'want',
#   '2',
#   'scandalous'],
#  ['hm'],
#  ['<name>', 'charlene', 'love', 'mis'],
#  ['<name>', "i'm", 'sory', 'least', 'friday'],
#  ['cant', 'fal', 'aslep'],
#  ['choke', 'retainer'],
#  ['ugh', 'beat', 'stupid', 'song', 'get', 'next', 'rude'],
#  ['<name>',
#   'u',
#   'watch',
#   'hils',
#   'london',
#   'u',
#   'wil',
#   'realise',
#   'tourture',
#   'weks',
#   'weks',
#   'late',
#   'watch',
#   'itonlinelol'],
#  ['get', 'news'],
#  ['storm', 'electricity', 'go'],
#  ['<name>', 'agred'],
#  ['slepy', 'even', 'late', 'fail'],
#  ['<name>', 'lady', 'gaga', 'tweted', 'impresed', 'video', 'leaking', 'know'],
#  ['convince',
#   'always',
#   'want',
#   'signal',
#   'give',
#   'damn',
#   'think',
#   'lose',
#   'another',
#   'friend'],
#  ['<name>',
#   'oh',
#   'bad',
#   'hope',
#   'get',
#   'beter',
#   "i've",
#   'ben',
#   'slep',
#   'isues',
#   'lately'],
#  ['wonder',
#   "i'm",
#   'awake',
#   '7am',
#   'write',
#   'new',
#   'song',
#   'plot',
#   'evil',
#   'secret',
#   'plot',
#   'muahahaha',
#   'oh',
#   'damn',
#   'secret',
#   'anymore'],
#  ['topic',
#   'map',
#   'talk',
#   'balisage',
#   'markup',
#   'conference',
#   '209',
#   'program',
#   'online',
#   'via',
#   '<name>',
#   'topicmaps'],
#  ['eat', 'something', 'know', 'kep', 'teling', 'thing', 'fod'],
#  ['tired',
#   'think',
#   "i'm",
#   'definitely',
#   'go',
#   'get',
#   'ear',
#   'infection',
#   'go',
#   'bed',
#   'quotearlyquot'],
#  ['way',
#   'home',
#   'n',
#   '2',
#   'deal',
#   'w',
#   'underage',
#   'girl',
#   'drink',
#   'gin',
#   'da',
#   'bus',
#   'talk',
#   'bout',
#   'kegers',
#   'damn',
#   'fel',
#   'old'],
#  ['<name>',
#   "i'm",
#   'sory',
#   'people',
#   'rude',
#   'isac',
#   'get',
#   'maners',
#   'know',
#   'beter',
#   'lewd'],
#  ['dam', 'server', 'stil', 'ned', 'hit', '80', 'al', 'koxpers', 'pas'],
#  ['fudge',
#   "bs'd",
#   'whole',
#   'paper',
#   'tired',
#   'ugh',
#   'hate',
#   'schol',
#   'time',
#   'slep'],
#  ['hate', 'cancer', 'hate', 'hate', 'hate'],
#  ['anoying', 'start', 'type', 'computer', 'midle', 'night'],
#  ['<name>', 'cant', 'slep'],
#  ['mised', 'anger', 'bus'],
#  ['fels', 'strong', 'contraction', 'want', 'go'],
#  ['socal', 'stoke', 'maybe', 'tomorow'],
#  ['screw', '<name>', '3', 'weks'],
#  ['<name>',
#   'yeah',
#   'fel',
#   'al',
#   'funy',
#   'cause',
#   'slept',
#   'enough',
#   'wake',
#   'mum',
#   'cause',
#   'sing',
#   'impresed'],
#  ['ned', 'skot', 'right'],
#  ['work', 'afternon'],
#  ['<name>', 'aw', 'would', 'unfolow', 'would', 'would', 'cry'],
#  ['much',
#   'beter',
#   'day',
#   'far',
#   'stil',
#   'quite',
#   'early',
#   'last',
#   'day',
#   'uds'],
#  ['<name>',
#   'lt3',
#   'gona',
#   'first',
#   'twiter',
#   'cause',
#   'amaze',
#   'lol',
#   'come',
#   'canada',
#   'would',
#   'anything',
#   'se',
#   'perform'],
#  ['pick', 'blackbery', 'midle', 'stret', 'crushed'],
#  ['feling',
#   'pack',
#   'hit',
#   'sfo',
#   'around',
#   'time',
#   'year',
#   'think',
#   "i'm",
#   'mising',
#   'something'],
#  ['<name>',
#   'midle',
#   'schol',
#   'elem',
#   'high',
#   'schols',
#   'wil',
#   'remain',
#   'open',
#   'ned',
#   'credit',
#   'graduate',
#   'cali',
#   'break'],
#  ['bed',
#   'time',
#   'hope',
#   'go',
#   'schol',
#   'tomorow',
#   'al',
#   'though',
#   'fel',
#   'wel',
#   'right'],
#  ['<name>',
#   'ah',
#   'wel',
#   'hop',
#   'could',
#   'learn',
#   'stuf',
#   'way',
#   'work',
#   'separate',
#   'thing',
#   'also'],
#  ["i'm", 'problem', 'photo', 'twiter', 'amf', "can't", 'se', 'face'],
#  ['<name>', 'oh', 'blow', 'tire', 'realy', 'go', 'send', 'batman', 'smoke'],
#  ['wna', 'take', 'bath'],
#  ['chocolate', 'milk', 'much', 'beter', 'straw', 'lack', 'say', 'straw'],
#  ['tired'],
#  ['<name>', 'hey', 'yu', 'lil', 'fucker', 'textd', 'yu'],
#  ['<name>',
#   'time',
#   'dif',
#   "i've",
#   'ben',
#   'wrap',
#   'day',
#   'day',
#   'stuf',
#   'havent',
#   'ben',
#   'tweting',
#   'talk',
#   'son',
#   'must',
#   'slep',
#   '6hrs'],
#  ['<name>', 'way', 'damn', 'suck', 'b', 'ok'],
#  ['suck', 'able', 'take', 'day', 'work', 'money', 'take', 'trip', 'sad'],
#  ['bed',
#   'sorta',
#   'today',
#   'god',
#   'sara',
#   'strep',
#   'think',
#   'angelina',
#   'share',
#   'water',
#   'b4',
#   'tell',
#   'wil',
#   'prob',
#   'get'],
#  ['<name>',
#   'recesion',
#   'hotel',
#   'restructure',
#   'acounts',
#   'do',
#   'ad',
#   'bit',
#   'presure',
#   'short',
#   'term',
#   "we'l",
#   'cope'],
#  ['<name>', 'get', 'dibs', 'sulu'],
#  ['<name>', 'aw', 'onward', 'upwards', 'yay', 'stil', 'sad', 'leave', 'bet'],
#  ['<name>', 'haha', 'por', 'aby', 'stil', 'get', 'sore'],
#  ['diesel', 'yaris', '70mpg', 'sad', 'available', 'u', "that'd", 'awesome'],
#  ['want',
#   'buy',
#   'great',
#   'album',
#   'unfortunately',
#   'dont',
#   'hav',
#   'enuf',
#   'fund',
#   'quotlong',
#   'time',
#   'noisyquot'],
#  ['<name>', 'al', 'honesty', 'pain', 'blech'],
#  ['ok',
#   'pasengers',
#   'one',
#   'alive',
#   "they're",
#   'al',
#   'dead',
#   'know',
#   'til',
#   'end',
#   'cry'],
#  ['home', 'alone', 'much'],
#  ['<name>', 'ia', 'much', 'realy', 'ben', 'hapy', 'coks', 'choice', 'single'],
#  ['<name>',
#   '<name>',
#   'fel',
#   'aslep',
#   'beach',
#   'put',
#   'enough',
#   'sunscren',
#   'lol'],
#  ['think',
#   'son',
#   'might',
#   'flu',
#   'cause',
#   'def',
#   'clean',
#   'stanky',
#   'puke',
#   'me',
#   'por',
#   'pumkpin'],
#  ['great',
#   'se',
#   'oin',
#   'amp',
#   'cynthia',
#   'hapy',
#   'diner',
#   'great',
#   'cute',
#   'litle',
#   'place',
#   'bad',
#   'oin',
#   'get',
#   'sick',
#   'afterwards'],
#  ['cant', 'give', '<name>', 'bday', 'nudge'],
#  ['al',
#   'woman',
#   'transfer',
#   'first',
#   'impresions',
#   'sexualmaternal',
#   'onto',
#   'le',
#   'threaten',
#   'man',
#   'weak'],
#  ['brother',
#   'blom',
#   'open',
#   'wekend',
#   'el',
#   'paso',
#   "i'l",
#   'buy',
#   'brick',
#   'enjoy',
#   'watch',
#   'brother',
#   'blom'],
#  ['say', 'mi', 'plurking'],
#  ['biten',
#   'blod',
#   'cat',
#   'way',
#   'rabies',
#   'bacterin',
#   'sems',
#   '7',
#   'shot',
#   '2',
#   'month',
#   'never',
#   'wash',
#   'cat',
#   'home',
#   'hate',
#   'water'],
#  ['mis', 'vobys'],
#  ['<name>', 'neither', 'elp'],
#  ['<name>',
#   'dude',
#   'favorite',
#   'sandwich',
#   'place',
#   'ever',
#   'um',
#   'take',
#   'picture'],
#  ['sad', 'shin', 'ae', 'get', 'maried', 'alex'],
#  ['<name>',
#   'sure',
#   'wil',
#   'twet',
#   'back',
#   'news',
#   'abuz',
#   'tr',
#   "knight's",
#   'leave',
#   'quotconfirmedquot',
#   'today',
#   'muy',
#   'triste'],
#  ['<name>', 'oh', 'thursday', 'exam', 'al', 'day', 'wednesday'],
#  ['mix', 'dentist', 'apt', 'afternon', 'reschedule', 'tomorow', '9am'],
#  ['<name>',
#   '<name>',
#   'think',
#   'excited',
#   'guy',
#   'move',
#   'realize',
#   'sad',
#   'se',
#   'go'],
#  ['god',
#   'morning',
#   'people',
#   'sun',
#   'definitly',
#   'spring',
#   'first',
#   'spring',
#   'hail',
#   'storm',
#   'car',
#   'dimple'],
#  ['<name>', 'love', "it'sakey", 'usb', 'stick', '4gb', 'australia'],
#  ['fresh',
#   'prince',
#   'slepy',
#   'sleps',
#   'nightly',
#   'routine',
#   'gota',
#   'go',
#   'dmv',
#   'early',
#   'tmrw'],
#  ['damit',
#   'hulu',
#   'desktop',
#   'totaly',
#   'screw',
#   'ability',
#   'talk',
#   'particular',
#   'port',
#   'one',
#   'dev',
#   'server',
#   "can't",
#   'watch',
#   'code'],
#  ['<name>',
#   'jealous',
#   'mom',
#   'talk',
#   '<name>',
#   'want',
#   'se',
#   'al',
#   'twitering',
#   'make',
#   'mi'],
#  ["can't", 'slep', 'kep', 'think', 'pupy', 'play', 'today'],
#  ["i'm",
#   'suposed',
#   'slep',
#   'get',
#   'much',
#   'amp',
#   'get',
#   'one',
#   'part',
#   'song',
#   'stuck',
#   'head',
#   'quotyour',
#   'jerk',
#   'iknowquot',
#   'blah'],
#  ['<name>', "what's", 'go', 'swetheart'],
#  ['freaking',
#   'dificult',
#   'get',
#   'systemwide',
#   'spelchecker',
#   'shit',
#   "i'd",
#   'setle',
#   'ofice',
#   'suite',
#   'one',
#   'stupid',
#   'unhelpful',
#   'window'],
#  ['last',
#   'one',
#   'month',
#   'due',
#   'sumer',
#   'strawbery',
#   'availble',
#   'chenai',
#   'market'],
#  ['<name>', 'work', '6am', 'gota', 'go', 'bed', 'son'],
#  ['<name>',
#   'corect',
#   'adore',
#   'pluck',
#   'put',
#   'arm',
#   'cuz',
#   'cryin',
#   'al',
#   'beter',
#   'hahaha'],
#  ['<name>', 'hi', 'im', 'ipod', 'cant', 'fal', 'aslep'],
#  ['dont', 'wana', 'work', '1830', 'tomorow', 'get', 'pay'],
#  ['fels', 'sad', 'coz', 'wasnt', 'able', 'play', 'guy'],
#  ['princecharming'],
#  ['cayogial',
#   'want',
#   'come',
#   'bz',
#   'sumer',
#   'sure',
#   'anymore',
#   "teacher's",
#   'life',
#   'sumer',
#   'suck'],
#  ['first',
#   'ever',
#   'drop',
#   'cal',
#   'mobile',
#   'cal',
#   '<name>',
#   'le',
#   'charge',
#   'data',
#   'even',
#   'though',
#   'data',
#   'pack'],
#  ['<name>', 'win', 'sigh', 'rakem'],
#  ['oh', 'time', 'real'],
#  ['darn',
#   'alergies',
#   'like',
#   'time',
#   'year',
#   'never',
#   'use',
#   'problem',
#   'either'],
#  ['oh', 'one', 'minute', 'late', 'oh', 'wel'],
#  ['<name>', 'damn', 'suck'],
#  ['<name>',
#   'want',
#   'come',
#   'bz',
#   'sumer',
#   'sure',
#   'anymore',
#   "teacher's",
#   'life',
#   'sumer',
#   'suck'],
#  ['<name>', 'website', 'give', 'virus', 'open', 'window', 'keep', 'pop'],
#  ['ah', 'big', 'scary', 'bug', 'fly', 'around', 'rom'],
#  ['wish',
#   'know',
#   'put',
#   'steal',
#   'heart',
#   'never',
#   'give',
#   'back',
#   'ocasionaly',
#   'like',
#   'like',
#   'lok'],
#  ['nasty', 'cough', 'cant', 'sick', 'huge', 'wekend', 'ahead'],
#  ['<name>', 'stone', 'cold', 'crazy'],
#  ["i'm", 'tired'],
#  ['shift', 'time', 'bye', 'biochem', 'wah'],
#  ['<name>',
#   "i'm",
#   'sure',
#   '1',
#   'wil',
#   'cum',
#   'play',
#   "i'm",
#   'workin',
#   'til',
#   'midnight'],
#  ['<name>', 'second', 'wish', 'rain'],
#  ['<name>',
#   'early',
#   'hapy',
#   'day',
#   'birth',
#   'case',
#   'make',
#   'tired',
#   'therapy',
#   'today',
#   'n',
#   'take',
#   'medicine',
#   'mishu',
#   'love',
#   'ya'],
#  ['damn', 'eric', 'anyone', 'else', 'ned', 'hair', 'play'],
#  ["i'm", 'fel', 'deflate', 'ugh', 'dog'],
#  ['alergies', 'suck', 'duck', 'nut', 'lt8', '<name>'],
#  ['wel', 'almost', 'god', 'day', 'gues', 'retry', 'tomorow'],
#  ['<name>', 'waraku', 'tasteles', 'expensive', 'portion', 'litle', 'waraku'],
#  ['<name>',
#   'sound',
#   'god',
#   'apreciate',
#   'sugestion',
#   'ben',
#   'wek',
#   "we're",
#   'stil',
#   'ofline',
#   'time',
#   'ask',
#   'refund'],
#  ['<name>', 'die', 'wait', 'magic', 'jack', 'read'],
#  ['<name>', 'youstinkatrespondingtotexts'],
#  ['wonder', 'karma', 'point', 'turn', '0'],
#  ['ned',
#   'pack',
#   'cali',
#   'canot',
#   'wait',
#   'think',
#   'glas',
#   'wine',
#   'order',
#   'celebrate',
#   'wekend',
#   'vaca',
#   'stil',
#   'work',
#   '2morow',
#   'tho'],
#  ['miserable', 'fel', 'like', 'im', 'gona', 'cry', 'sux'],
#  ['<name>',
#   'wel',
#   'run',
#   'ber',
#   'leave',
#   'sure',
#   'eta',
#   'wait',
#   'wait',
#   'bleh',
#   'gona',
#   'long',
#   'nite',
#   'methinks'],
#  ['<name>',
#   'nose',
#   'stud',
#   'fel',
#   "can't",
#   'find',
#   'loks',
#   'like',
#   "i'l",
#   'head',
#   'amsterdam',
#   'today',
#   'get',
#   'new',
#   'one'],
#  ['claire', '<name>', 'love', 'show', 'get', 'ofice', '5am', 'radio'],
#  ['pat',
#   'phily',
#   '2',
#   'love',
#   'mm',
#   'chesesteak',
#   'mi',
#   'boyfriend',
#   'love',
#   'vacation'],
#  ['sigh', "i'm", 'go', 'bed', 'fel', 'right', 'anymore'],
#  ['focus',
#   'tom',
#   'much',
#   'se',
#   'beloved',
#   'barack',
#   'oh',
#   'must',
#   'vote',
#   'por',
#   'president',
#   '626',
#   'vote'],
#  ['<name>', 'epicentre', 'whelock', 'place', 'tourists'],
#  ['depresed', 'watch', 'think', 'dance'],
#  ['cro', 'cause', "i'm", 'stick', 'twidling', 'thumb', 'ugh'],
#  ['mis', '16', 'th'],
#  ['<name>',
#   'know',
#   'like',
#   'say',
#   'idea',
#   'long',
#   'take',
#   'investigate',
#   'stuf'],
#  ['cant', 'slep', 'im', 'sore', 'move'],
#  ['<name>', 'awe', 'mis', 'baby'],
#  ['<name>', 'answer', 'never', 'learn', 'write', 'french', 'basic', 'stuf'],
#  ['chocolate', 'never', 'say'],
#  ['achieve',
#   'new',
#   'apreciation',
#   'xml',
#   'build',
#   'script',
#   'realy',
#   'painful',
#   'cumbersome'],
#  ['<name>', "i'm", 'awake', 'il', 'nap', 'afternon'],
#  ['<name>', 'cant', 'anything'],
#  ['stil', 'neds', 'another', '6', 'hour', 'slep'],
#  ["i'm", 'work'],
#  ['rip', 'leonardo', 'great', 'mini', 'fidler', 'crab'],
#  ['morning', 'tweple', 'way', 'early'],
#  ['last', 'day', 'work', 'uni', 'today', 'sad', 'time'],
#  ['<name>', 'thanks', 'nemah', "i'm", 'gona', 'close', 'izy', 'yet', 'far'],
#  ['head', 'hurt', 'bad', 'could', 'scream'],
#  ['go',
#   'im',
#   'tired',
#   'airmatras',
#   'break',
#   'somewhere',
#   'im',
#   'even',
#   'pain'],
#  ['new',
#   'work',
#   'welnes',
#   'chalenge',
#   'go',
#   'wel',
#   'comited',
#   'check',
#   'email',
#   'betwen',
#   '10',
#   'pm',
#   '6',
#   'fail',
#   'first',
#   'day',
#   'twice'],
#  ['new',
#   'blog',
#   'post',
#   'blog',
#   'auto',
#   'insuran',
#   'find',
#   'auto',
#   'insurance',
#   'policy',
#   'ben',
#   'expire',
#   'careles',
#   'meanw'],
#  ['al', 'bestfriends', 'mia', 'wat'],
#  ['oh', 'men', 'realy', "can't", 'se', 'face', "c'mon", 'guy'],
#  ["i'm",
#   'show',
#   'age',
#   'renew',
#   'tag',
#   'last',
#   'wek',
#   'go',
#   '20',
#   'get',
#   'insurance',
#   'renewal',
#   'email',
#   'today',
#   'go',
#   '10',
#   'wana',
#   'old'],
#  ['sole', 'suporter', 'sole', 'suporter'],
#  ['hate',
#   'finish',
#   'al',
#   'work',
#   "there's",
#   'stil',
#   '1',
#   '25',
#   'hour',
#   'leave',
#   'work',
#   'time'],
#  ['<name>', 'urgh', 'stop', 'guy'],
#  ['stil', 'mising', 'husband', 'realy', 'want', 'home'],
#  ['mis', 'pupy'],
#  ['2', 'day', 'month', 'leave', '40mb', 'leave', 'onpeak', 'downloads'],
#  ['<name>', 'get', 'memo', 'loks', 'amazing'],
#  ['<name>',
#   "i've",
#   'give',
#   'piza',
#   'kid',
#   'would',
#   'never',
#   'let',
#   'fav',
#   'hot',
#   'one'],
#  ['reading',
#   'tabloid',
#   "people's",
#   'live',
#   'think',
#   "i'm",
#   'gona',
#   'mine',
#   'baby',
#   'leave'],
#  ['<name>', 'yearling', 'pet', 'home', 'die', 'sad', 'whole', 'family'],
#  ['fun', 'sun', 'hm', 'hel', 'cold'],
#  ['get',
#   'giant',
#   'splinter',
#   'stick',
#   'underneath',
#   'finger',
#   'nail',
#   'today',
#   'mupets',
#   'hurt',
#   'get',
#   'go',
#   'first',
#   'aid',
#   'first',
#   'time'],
#  ['<name>',
#   'hate',
#   'change',
#   'course',
#   "we're",
#   'fan',
#   'life',
#   'lt3',
#   'oh',
#   'meet',
#   'rob',
#   'something',
#   'go',
#   'horibly',
#   'wrong'],
#  ['feling', 'sad', 'reason'],
#  ['wel',
#   'fuck',
#   'new',
#   'pain',
#   'med',
#   'od',
#   'warning',
#   'actualy',
#   'aplies',
#   "can't",
#   'take',
#   'chan',
#   'displease'],
#  ['upload',
#   'new',
#   'blog',
#   'painful',
#   'story',
#   '80',
#   'year',
#   'old',
#   'man',
#   'cry',
#   'want',
#   'die',
#   'sad'],
#  ['<name>', 'think', 'want', 'detail'],
#  ['<name>', 'hi', 'mary', 'popins'],
#  ['<name>',
#   'adicting',
#   'kind',
#   'curse',
#   'night',
#   'time',
#   'everytime',
#   'one',
#   'fel',
#   'like',
#   'make',
#   'music',
#   'afterwards'],
#  ['last', 'twet', 'send', 'bad', 'phone'],
#  ['<name>',
#   'omg',
#   'ur',
#   'alive',
#   'lol',
#   '2day',
#   'go',
#   'slow',
#   "i'm",
#   'go',
#   'insane',
#   'gr',
#   'anything',
#   'tonight'],
#  ['headache', "i'm", 'go', 'bed', 'godnight'],
#  ['<name>', 'watch', 'parental', 'control'],
#  ['<name>',
#   'get',
#   'california',
#   'vintage',
#   'ahahah',
#   'best',
#   'dreses',
#   'want',
#   'dont',
#   'ebay'],
#  ['saw', 'pic', 'past', 'thanksgiving', 'sad', 'grandma'],
#  ['<name>', 'wont', 'let'],
#  ['tok', 'shift', 'tomorow', 'realy', 'fel', 'like', 'work', 'right'],
#  ['money', 'phone'],
#  ['spend',
#   'last',
#   'night',
#   'aampe',
#   'er',
#   'wife',
#   'tangle',
#   'whels',
#   'daughter',
#   'amp',
#   'hit',
#   'deck',
#   'dislocation',
#   'amp',
#   'fracture',
#   'result'],
#  ['<name>',
#   '9',
#   'day',
#   "i'm",
#   'ready',
#   'visit',
#   'torchwod',
#   'se',
#   "they've",
#   'heard',
#   'anything'],
#  ['<name>', 'bris', "can't", 'hear', 'thunder'],
#  ['bec', 'v', 'fat', 'fod', 'winer', 'fat', 'fod', 'weknend', 'il', 'beat'],
#  ['bad', 'red', 'devil', 'disapointing', 'say', 'least'],
#  ['dream', 'prety', 'beach', 'beach', 'wake'],
#  ['<name>',
#   '3ware',
#   '9650se',
#   'fast',
#   'enough',
#   '3x',
#   'x25m',
#   'sd',
#   'raid',
#   '5',
#   '80mhz',
#   'iop',
#   'hpt',
#   'might',
#   'try',
#   'adaptec',
#   '5405',
#   '1',
#   '2ghz'],
#  ['da', 'heck', 'wil', 'garage', 'man', 'get', 'ask'],
#  ['ate', 'mandy', 'please', 'forgive', 'realy', 'sory', 'wana', 'lose', 'bf'],
#  ['<name>',
#   'um',
#   'yeah',
#   "that's",
#   'probably',
#   'prety',
#   'god',
#   'note',
#   'self',
#   'e'],
#  ['plane', 'ticket', 'expensive'],
#  ['<name>',
#   '<name>',
#   'um',
#   'yeah',
#   "that's",
#   'probably',
#   'prety',
#   'god',
#   'note',
#   'self',
#   'e'],
#  ['neds', 'job', 'badly'],
#  ['<name>', 'damn', 'wish'],
#  ['go',
#   'di',
#   'bela',
#   'cofe',
#   'roaster',
#   'today',
#   'ask',
#   'job',
#   'person',
#   'neded',
#   'speak',
#   'holiday',
#   'fb'],
#  ['<name>',
#   'play',
#   'late',
#   'part',
#   'vodo',
#   'vilage',
#   'part',
#   'coop',
#   'lose',
#   'usual',
#   'partner'],
#  ['<name>',
#   'nite',
#   "i'm",
#   'n',
#   'bore',
#   'oposed',
#   'almost',
#   'slep',
#   'frm',
#   'b',
#   '4'],
#  ['bad', 'friend'],
#  ['<name>',
#   'hapy',
#   'birthday',
#   'hope',
#   'awesome',
#   'day',
#   'se',
#   'next',
#   'last',
#   'night'],
#  ['<name>', 'im', 'shit', 'right', 'im', 'vacation', 'get', 'workin'],
#  ['<name>', 'il', 'oir'],
#  ['<name>', 'gues', 'go', 'girlie', "i'm", 'stil', 'gym', 'work', '630am'],
#  ['would',
#   'wish',
#   'severe',
#   'migrains',
#   'would',
#   'stop',
#   "doc's",
#   'prescription',
#   'arent',
#   'work'],
#  ['<name>', 'mised', 'game'],
#  ['<name>',
#   'internet',
#   'last',
#   'night',
#   'er',
#   'bril',
#   'masive',
#   'explosion',
#   'end',
#   'nearby',
#   'gas',
#   'work',
#   'er',
#   'standby'],
#  ['<name>', 'cuz', 'airline', 'super', 'lame'],
#  ['<name>', 'stil', 'pity', 'come', 'lamb', 'though'],
#  ['<name>',
#   "i'm",
#   'sory',
#   'hear',
#   'optimist',
#   'thing',
#   'wil',
#   'get',
#   'beter',
#   'al',
#   'u'],
#  ['do',
#   'paint',
#   'al',
#   'bedrom',
#   'furniture',
#   'stil',
#   'table',
#   'wil',
#   'wait',
#   'move',
#   'ugh',
#   'move',
#   'heat'],
#  ["i'm", 'tired', 'insomnia'],
#  ['<name>',
#   'hungry',
#   'fol',
#   'il',
#   'probably',
#   'never',
#   'se',
#   'krispy',
#   'kreme',
#   'enjoy',
#   'close'],
#  ['<name>', 'airport', 'didnt', 'show', 'tonight', 'homo'],
#  ['hate',
#   'bakersfield',
#   'hate',
#   'port',
#   'let',
#   'go',
#   'home',
#   'already',
#   'want',
#   'start',
#   'vacation'],
#  ['<name>'],
#  ['loking',
#   'desktop',
#   'twiter',
#   'ap',
#   'wil',
#   'actualy',
#   'let',
#   'ace',
#   'urls',
#   'sugestions',
#   'like',
#   'twitle',
#   'linking'],
#  ['people', 'house', 'know', 'close', 'dors'],
#  ['complete',
#   'facebok',
#   'quiz',
#   'time',
#   'morning',
#   'especialy',
#   'friday',
#   'morning'],
#  ['<name>', 'amp', '<name>', 'hungry'],
#  ['<name>',
#   'like',
#   'posibility',
#   'left',
#   'side',
#   'brain',
#   'hurting',
#   'thing',
#   'caled',
#   'vp',
#   'shunt',
#   'posible',
#   'death'],
#  ['cancel', 'wow'],
#  ['want',
#   'make',
#   'music',
#   'profile',
#   'money',
#   'know',
#   'write',
#   'music',
#   'know',
#   'play',
#   'instrument',
#   'studio'],
#  ['<name>',
#   'yeah',
#   "i'm",
#   'sad',
#   'quotravenclawquot',
#   'acount',
#   'love',
#   'acount',
#   'bit'],
#  ['115',
#   'hear',
#   'helicopter',
#   'fly',
#   'house',
#   "that's",
#   'kind',
#   'weird',
#   'news',
#   'headache',
#   'back',
#   'bo'],
#  ['<name>', 'oh', 'always', 'lt3'],
#  ['back',
#   'schol',
#   'm',
#   "suhana's",
#   'last',
#   'day',
#   'ft',
#   'ocu',
#   'okay',
#   "i'm",
#   'play',
#   'altnoy'],
#  ['pol', 'try', 'get', 'work', 'powerpoint', 'avail'],
#  ['tok',
#   'math',
#   'test',
#   'today',
#   'day',
#   'test',
#   'teacher',
#   'say',
#   'bring',
#   'calculator',
#   'luke',
#   'confident',
#   'teacher',
#   'decide',
#   'calcs'],
#  ['omg',
#   'concert',
#   'awesome',
#   'madrigal',
#   'give',
#   'chils',
#   'almost',
#   'every',
#   'piece',
#   'broks',
#   'also',
#   'caled',
#   'alumnus',
#   'didnt',
#   'get',
#   'go'],
#  ['<name>',
#   'yeah',
#   'terible',
#   'cockatos',
#   'hard',
#   'live',
#   'emotional',
#   'god',
#   'thing',
#   'find',
#   'though'],
#  ['late', 'nothin', '2'],
#  ['think', 'vog', 'make', 'sick', 'think', 'feling', 'slightly', 'achy'],
#  ['<name>', 'watch', 'harper', 'island', 'lol', 'vodka', 'involve'],
#  ['homework', 'sux', 'big', 'time', 'math', 'bad'],
#  ['<name>',
#   'would',
#   'ben',
#   'beter',
#   'imo',
#   'let',
#   'play',
#   'al',
#   '3',
#   'song',
#   'provide',
#   'start',
#   'quotget',
#   'itquot',
#   'black'],
#  ['3wordsaftersex', 'never', 'start'],
#  ['sometimes',
#   'wish',
#   'thing',
#   'could',
#   'go',
#   'back',
#   'way',
#   'begining',
#   'last',
#   'sumer'],
#  ['download',
#   'new',
#   'twiterfon',
#   'update',
#   'thinking',
#   'fix',
#   'typing',
#   'problem',
#   'new',
#   'twets'],
#  ['<name>', "trudy's", 'burnet', 'one', 'north', 'one', 'go'],
#  ['<name>', 'fel', 'way', 'gues', 'mater', 'wil', 'always', 'meme'],
#  ['cant',
#   '30',
#   'minute',
#   'treadmil',
#   'do',
#   '30',
#   'minute',
#   'today',
#   'already',
#   'gona',
#   '20',
#   'minute'],
#  ["i'm", 'confused'],
#  ['friend',
#   'like',
#   'vaiko',
#   'nedumaran',
#   'lte',
#   'ned',
#   'enemy',
#   'wrong',
#   'advice',
#   'wrong',
#   'time',
#   'lead',
#   'numerous',
#   'death',
#   'amp',
#   'lost',
#   'cause',
#   'wel'],
#  ['work', 'day', '7', '7'],
#  ['chilin',
#   'romies',
#   "can't",
#   'wait',
#   'zombie',
#   'clwn',
#   'cr',
#   'gona',
#   '68',
#   'weks'],
#  ['love', 'guitar', 'play', 'think', 'sound', 'magnificent', 'beter'],
#  ['<name>',
#   'refund',
#   'retrieve',
#   'acounts',
#   'take',
#   'like',
#   'wek',
#   'hop',
#   'thief',
#   'use',
#   'hack',
#   'permaban'],
#  ['<name>', 'im', 'cry', 'lol'],
#  ['cute',
#   'malay',
#   'girl',
#   'come',
#   'semy',
#   'rom',
#   'rent',
#   'sadly',
#   'think',
#   'guyfreind',
#   'bit',
#   'misleading',
#   'disapointing',
#   'lol'],
#  ['<name>',
#   'epicentre',
#   'whelock',
#   'place',
#   '250',
#   'unit',
#   'amp',
#   'tourist',
#   'start',
#   'today'],
#  ['hate',
#   'new',
#   'mt',
#   'dew',
#   'comercial',
#   'one',
#   'giant',
#   'mosquito',
#   'scar',
#   'groses',
#   'al',
#   'time'],
#  ['come', 'knight', 'ben', 'wel', '4', 'hour'],
#  ['super',
#   'ken',
#   'drive',
#   'home',
#   'rain',
#   'aditional',
#   'concentration',
#   'require',
#   'realy',
#   'wana',
#   'deal'],
#  ['<name>', 'aw', 'u', "can't", 'let', 'secret'],
#  ['<name>',
#   'im',
#   'sory',
#   'think',
#   'stick',
#   'least',
#   'compare',
#   'use',
#   'lok',
#   'like'],
#  ['transport',
#   'church',
#   'wont',
#   'make',
#   'im',
#   'crush',
#   'oh',
#   'wel',
#   'time',
#   'asignments',
#   'supose',
#   'throat',
#   'realy',
#   'hurt'],
#  ['hate',
#   'se',
#   'pregnant',
#   'woman',
#   'smoke',
#   'iresponsible',
#   'n',
#   'selfish',
#   'sad',
#   'ultimately',
#   'baby',
#   'one',
#   'sufers'],
#  ['lie', 'lie', 'cant', 'avoid', 'lie', 'practicaly', 'everything'],
#  ['twitascope', 'rock', 'sock', 'go', 'away', 'already'],
#  ['drive', 'back', 'home', 'forget', 'piece', 'cake', '<name>'],
#  ['<name>',
#   'try',
#   'jump',
#   'without',
#   'trampoline',
#   'like',
#   'thud',
#   'eat',
#   'cokie'],
#  ['everytime',
#   'send',
#   'email',
#   'coach',
#   'fel',
#   'ned',
#   'practice',
#   'shity',
#   'bals',
#   'lol'],
#  ['pising', 'let', 'folow', 'ericka'],
#  ['go',
#   'slep',
#   'peaceful',
#   'want',
#   'hear',
#   'say',
#   'god',
#   'night',
#   'hapen',
#   'god',
#   'night',
#   'everyone'],
#  ['mum',
#   'try',
#   'make',
#   'fel',
#   'ebter',
#   'stop',
#   'vote',
#   'adn',
#   'win',
#   'shortstack',
#   'almost',
#   'cry'],
#  ['<name>', 'close', 'taco', 'one', 'spot', 'late'],
#  ['<name>',
#   'um',
#   'bout',
#   'em',
#   'aint',
#   'get',
#   '2',
#   'se',
#   'da',
#   'game',
#   'se',
#   'dey',
#   'survive',
#   'anotha',
#   'game',
#   'da',
#   'series',
#   'due',
#   'notin',
#   'lebron',
#   'im',
#   'guesin'],
#  ['think', 'much', "i'm", 'work'],
#  ['forget', 'live', 'jonas', 'brother', 'facebok'],
#  ['sen', 'mufin', 'two', 'whole', 'day'],
#  ['<name>', "i'l", 'mi', "y'al", 'back', 'give', '<name>', 'regard'],
#  ['gap', 'year', 'go', 'quick'],
#  ['admit', "i'm", 'bit', 'bum', 'friend', 'walk', 'today'],
#  ['<name>',
#   'girl',
#   'blunt',
#   'thought',
#   'right',
#   'absolutly',
#   'great',
#   'day',
#   'stresors',
#   'come',
#   'home'],
#  ['twiter', 'ben', 'hack'],
#  ['find', 'mj', 'mouse', 'flat', 'dj', 'course', 'none', 'leave', 'size'],
#  ['<name>', 'wont', 'time', 'buy', 'ned', 'new', 'binder', 'pa'],
#  ['<name>', 'hahaha', 'wel', 'try', 'ugly'],
#  ['25man', 'ulduar', 'hard'],
#  ['<name>', 'even', 'want', 'know', 'know', 'vhemt', 'go', "we'd", 'mi'],
#  ['<name>',
#   "that's",
#   'awesome',
#   'wekend',
#   "can't",
#   'go',
#   "i'm",
#   'move',
#   'sat',
#   'lot',
#   'fun',
#   'though'],
#  ['night',
#   'twiter',
#   'world',
#   'stil',
#   'cant',
#   'believe',
#   'thomas',
#   'thing',
#   "tomorow's",
#   'guna',
#   'funsad'],
#  ['<name>', 'hapening'],
#  ['<name>', 'oh', 'hug'],
#  ['<name>',
#   'bore',
#   'talk',
#   'someone',
#   "they're",
#   'busy',
#   'something',
#   'else',
#   'kinda',
#   'bumer',
#   'idk'],
#  ['<name>', 'know', 'thing', 'lt3'],
#  ['omgnes',
#   '118',
#   'pm',
#   'ned',
#   'beup',
#   'early',
#   'set',
#   'garage',
#   'sale',
#   'start',
#   '8am',
#   'wish',
#   'say',
#   '9am',
#   "i'm",
#   'beat'],
#  ['<name>', 'kno', 'yal', 'partyin'],
#  ['okay', 'twiter', 'sudenly', 'change', 'respond', 'mesages'],
#  ['ugh',
#   'dad',
#   'tell',
#   'read',
#   'article',
#   'kavya',
#   'shivashankar',
#   'spelin',
#   'girl',
#   'like'],
#  ['decide',
#   'mater',
#   'god',
#   'hair',
#   'loks',
#   'curly',
#   'justify',
#   'burn',
#   'get',
#   'curler',
#   'hand',
#   'cover',
#   'suck'],
#  ['go', 'slep', 'gona', 'fal', 'aslep', 'play', 'aps', 'tmrw', 'go', 'suck'],
#  ['<name>', 'yea', 'gota', '730'],
#  ['hate', 'bf', 'beat', 'da', 'dog', 'gues', 'way', 'teach', 'pit'],
#  ['sprain',
#   'ankle',
#   'like',
#   'realy',
#   'badly',
#   'tear',
#   'stufs',
#   'hurt',
#   'birthday',
#   'wekend'],
#  ["can't",
#   'believe',
#   'metal',
#   'gear',
#   'solid',
#   'song',
#   'steal',
#   "i'm",
#   'disapointed'],
#  ['think',
#   'may',
#   'break',
#   'toe',
#   'bar',
#   'tonight',
#   'thanks',
#   'drink',
#   'girl',
#   'stepin',
#   'al'],
#  ['one',
#   'sale',
#   'do',
#   'today',
#   'work',
#   'explored',
#   'balcony',
#   'big',
#   'theater',
#   'w',
#   'coworkers',
#   'fun',
#   'day',
#   'void',
#   'chili',
#   'fry',
#   'tip'],
#  ['<name>',
#   'wish',
#   'leave',
#   '4',
#   'dead',
#   'first',
#   "i'd",
#   'ned',
#   'something',
#   'play'],
#  ['<name>'],
#  ['<name>', 'story', 'reminds', 'living', 'portugal'],
#  ['<name>',
#   'youre',
#   'diabetic',
#   'dad',
#   'amp',
#   'might',
#   'sure',
#   'stil',
#   'alowed',
#   'eat',
#   'sugar',
#   'throughout',
#   'day'],
#  ['spiled',
#   'ber',
#   'al',
#   'leg',
#   'waste',
#   'half',
#   'ber',
#   'home',
#   'meet',
#   'cute',
#   'girl',
#   'god',
#   'conversation'],
#  ['romate', '<name>', 'love', 'ignore'],
#  ['<name>', "i'l", 'make', 'nachos', 'tomorow', 'beter', 'would', 'make'],
#  ['<name>', 'yeah', 'ampdont', 'judge', 'pilow'],
#  ['scary',
#   'lightning',
#   'thunder',
#   "i'm",
#   'glad',
#   'go',
#   'slep',
#   'hope',
#   "i'm",
#   'late',
#   'schol',
#   'tomorow',
#   'haha'],
#  ['teth', 'head', 'hurt'],
#  ['hate', 'rob', 'zombie', 'movie', 'amp', 'smel', 'wed', 'vom'],
#  ['<name>',
#   'math',
#   'science',
#   'strong',
#   'think',
#   'duno',
#   'bout',
#   'geography',
#   'like',
#   '1',
#   'day',
#   'study',
#   '12',
#   'year',
#   'work'],
#  ['wait', 'line', 'tryst'],
#  ['hope',
#   'get',
#   'job',
#   'cuz',
#   'ned',
#   'apartment',
#   "i'm",
#   'drunk',
#   'amp',
#   'mi',
#   'lil',
#   'punkin',
#   'tehe'],
#  ['get',
#   'home',
#   'want',
#   'read',
#   'last',
#   'chaper',
#   'break',
#   'dawn',
#   'cause',
#   'dont',
#   'want',
#   'beover'],
#  ['ned', 'hold', 'gnite'],
#  ['hang',
#   'sam',
#   'bily',
#   'veronica',
#   'go',
#   'schol',
#   'tomorow',
#   'take',
#   'sam',
#   'body',
#   'shop',
#   'dang',
#   'car',
#   'acidents'],
#  ['arested', 'development', 'sad'],
#  ['<name>', 'wicked', 'time', 'leave', 'come', 'cant', 'stay', 'night'],
#  ['omg',
#   'kep',
#   'lose',
#   'folowers',
#   'sad',
#   'want',
#   '90',
#   'one',
#   'day',
#   'thats',
#   'goal'],
#  ['fel', 'deflated', 'dogy'],
#  ['<name>', 'wana', 'se', 'hair', 'hows', 'everyone'],
#  ['empty',
#   'trash',
#   'mac',
#   'one',
#   'dificult',
#   'thing',
#   'ever',
#   'do',
#   'life',
#   '8,0',
#   'picture',
#   'go'],
#  ['im',
#   'contact',
#   'paws',
#   'philipines',
#   'find',
#   'quottigerquot',
#   'new',
#   'owner',
#   'im',
#   'sad',
#   'love',
#   'dog',
#   'much'],
#  ['get',
#   'home',
#   'want',
#   'read',
#   'last',
#   'chaper',
#   'break',
#   'dawn',
#   'cause',
#   'dont',
#   'want'],
#  ['aw', 'pray', 'aroyo', 'family', 'everyone'],
#  ['<name>',
#   "there's",
#   'manual',
#   'proces',
#   'take',
#   '4ever',
#   'outlok',
#   'database',
#   'pf',
#   'crapy',
#   'msft',
#   'product'],
#  ['fudge', 'movie', 'store', 'close'],
#  ['alo', 'sad', 'quiet', 'empty', 'tonight'],
#  ['<name>',
#   'hahahaha',
#   'horible',
#   'others',
#   'sing',
#   "i'm",
#   'sure',
#   'could',
#   'work',
#   'wish',
#   'could',
#   'aford',
#   'drum',
#   'set'],
#  ['<name>', 'never', 'answer', 'dm', 'send', 'ned', 'info'],
#  ['try',
#   'get',
#   'pilot',
#   'first',
#   'season',
#   'friday',
#   'night',
#   'light',
#   'oh',
#   'gosh',
#   'pa',
#   'tisue'],
#  ['<name>', 'aw', 'head', 'cancel', 'trip', 'ausie'],
#  ['cystic', 'lacrimal', 'infectection', 'eye', 'face', 'swolen', 'hurt'],
#  ['<name>', 'think', 'anyone', 'caught'],
#  ['ned', 'sleping', "i'm", 'even', 'tire'],
#  ['0'],
#  ['oh', 'nevermind', 'think', 'thing', 'unsalvageable'],
#  ['lyin', 'bed', 'far', 'early'],
#  ['sad', 'christian', 'lacroix', 'file', 'bankruptcy'],
#  ['dont', 'fel', 'god', 'al', 'fuck'],
#  ['agre', 'work', 'double', 'shift'],
#  ['loks', 'like', "i'l", 'never', 'go', 'zo'],
#  ['<name>', 'oh', 'por', 'girl', "i'l", 'email', 'rely', 'october', 'mr'],
#  ['wil', 'medhurst', 'play'],
#  ['<name>', 'bad', 'time'],
#  ['argh', 'anger', 'hose', 'leak', 'water', 'al', 'new', 'floating', 'flor'],
#  ['go', 'dread', 'dmv', 'tomorow'],
#  ['<name>', "i'm", 'bit', "ben's", 'thaied'],
#  ['english', 'clas', 'work', 'interactive', 'oral'],
#  ['<name>', 'thank', 'rec', 'work'],
#  ['<name>',
#   "i'm",
#   'sory',
#   'excite',
#   'tomorow',
#   'night',
#   'karaoke',
#   'get',
#   'anything',
#   'special',
#   'bday'],
#  ['pupy',
#   'gizmo',
#   'h8s',
#   'haha',
#   'stil',
#   'growls',
#   'always',
#   'lok',
#   'back',
#   'long',
#   'pruple',
#   'scar',
#   'fingie'],
#  ['know', 'ima', 'work', 'tomorow', 'wit', 'body', 'dis', 'sore', 'ugh'],
#  ['71', 'wo'],
#  ['<name>', 'yeah', 'plus', 'litle', 'far', 'walk', "pinochio's", 'sushi'],
#  ["i'm",
#   'feling',
#   'presure',
#   'head',
#   'always',
#   'kick',
#   'nasty',
#   'headache',
#   "i'm",
#   'loking',
#   'forward'],
#  ['taylor',
#   'swift',
#   'joe',
#   'jonas',
#   'loked',
#   'realy',
#   'god',
#   'together',
#   "i'm",
#   'kinda',
#   'sad',
#   'break'],
#  ["i'm",
#   'supose',
#   'turn',
#   'sentence',
#   'outline',
#   'research',
#   'paper',
#   'within',
#   'hour',
#   'online',
#   'neck',
#   'hurt'],
#  ['lady', 'acros', 'way', 'miscariage', 'say', 'prayer'],
#  ['god', 'want', 'slep'],
#  ['<name>', 'oh', 'thunderstorms', 'bo', 'always', 'make', 'power', 'go'],
#  ['fel', 'deflated', 'dogy'],
#  ['find',
#   'bok',
#   'start',
#   'real',
#   'paperbound',
#   'journal',
#   'tonight',
#   'anoying',
#   'zit',
#   'lip',
#   'make',
#   'lok',
#   'like',
#   'herpes'],
#  ['rat',
#   'rock',
#   'nashvile',
#   'tonite',
#   'one',
#   'thing',
#   'suck',
#   'encore',
#   'like',
#   '80',
#   'stil',
#   'fun',
#   'show',
#   'pearcy',
#   'hot',
#   'bad',
#   'boy',
#   'lok'],
#  ['feling', 'bad', 'get', 'bad', 'news', 'mum'],
#  ['<name>', 'dun', 'wana'],
#  ['<name>',
#   'damn',
#   'girl',
#   "i'm",
#   'ya',
#   'gota',
#   'let',
#   'know',
#   'get',
#   'kit',
#   'together',
#   'amp',
#   'get',
#   'flyer',
#   'next',
#   'wekend',
#   'iquotm'],
#  ['<name>',
#   'dbl',
#   'bo',
#   'sick',
#   'flipin',
#   'blow',
#   'bahaha',
#   'kno',
#   'dont',
#   'many',
#   'friend',
#   'either',
#   'fel',
#   'lame',
#   'haha'],
#  ['<name>', 'thats', 'think', 'time', 'gona', '1'],
#  ['pep',
#   'stil',
#   'fun',
#   'time',
#   'gota',
#   'slep',
#   'tho',
#   'work',
#   'col',
#   'hot',
#   'chick',
#   'none',
#   'col',
#   'mising'],
#  ['fel', 'like', 'work', 'think', 'twet', 'often'],
#  ['fels', 'sick', 'stomach', 'idk'],
#  ['vineri',
#   'nimic',
#   'special',
#   'sau',
#   'probabil',
#   'un',
#   'alt',
#   'wekend',
#   'pierdut'],
#  ['count', 'hour', 'lose', 'sunshine', 'wekend'],
#  ['<name>',
#   'dude',
#   'saw',
#   'sf',
#   'pic',
#   'loks',
#   'like',
#   'mini',
#   'excursion',
#   'prety',
#   'kick',
#   'se',
#   'sun',
#   'tho'],
#  ['home', 'safely', 'hungry'],
#  ['<name>', 'um', 'throw', '<name>', 'van', 'yesterday', 'take', 'er'],
#  ['get',
#   'final',
#   'table',
#   'go',
#   'third',
#   'think',
#   "i'l",
#   'get',
#   'fre',
#   'seat'],
#  ['god', 'morning', 'work', 'morning', 'gut', 'lol', 'nevermind'],
#  ['work',
#   'morning',
#   'friend',
#   'get',
#   'party',
#   'stupid',
#   'bery',
#   'lite',
#   'flashing',
#   'red',
#   'mesages'],
#  ['fb', 'boring', 'wana', 'sing', 'right'],
#  ['<name>', 'link', 'work'],
#  ['<name>',
#   'hahaha',
#   'know',
#   'anyone',
#   'anything',
#   'except',
#   'power',
#   'lol',
#   'live',
#   'buble'],
#  ['humpalow', 'um', 'ya', 'think', 'cel', 'die'],
#  ['last', 'day', 'work', 'sick', 'bone'],
#  ['fel', 'like', "i'm", 'house', 'arest'],
#  ['love', 'like', 'war', 'easy', 'begin', 'hard', 'end', 'fiuh'],
#  ['<name>', 'ur', 'suposed', 'bk', 'tho'],
#  ['<name>',
#   'know',
#   'shortage',
#   'shels',
#   'crab',
#   'use',
#   'beach',
#   'due',
#   'beach',
#   'comber',
#   'sad'],
#  ['oh', 'nighty', 'night'],
#  ['<name>',
#   'must',
#   'new',
#   'music',
#   'slep',
#   'give',
#   'u',
#   'chapter',
#   '1',
#   'might',
#   'die',
#   'first',
#   'though',
#   'hury'],
#  ['stupid', 'toth', 'hurt'],
#  ['<name>',
#   'love',
#   'song',
#   'quottogetherquot',
#   "that's",
#   'quothisquot',
#   'song',
#   'wel',
#   'think',
#   'stil'],
#  ['ready', 'go', 'schol'],
#  ['<name>',
#   'computer',
#   'break',
#   'break',
#   'laptop',
#   'use',
#   'phone',
#   'ah',
#   'stil',
#   'cause',
#   'fuck',
#   'order'],
#  ['<name>',
#   'god',
#   'holiday',
#   'chalet',
#   'sight',
#   'lok',
#   'v',
#   'similar',
#   'one',
#   'go',
#   'home',
#   'today'],
#  ['sad',
#   'economy',
#   'hear',
#   'another',
#   'friend',
#   'lose',
#   'job',
#   'sad',
#   'reminder'],
#  ['<name>',
#   "i'm",
#   'start',
#   'fel',
#   'realy',
#   'panicky',
#   'anxious',
#   'something',
#   'bad',
#   'hapened',
#   'co',
#   'sems',
#   'like',
#   'ben',
#   'age'],
#  ['dog', 'run', 'away'],
#  ['<name>', 'suck', 'bad'],
#  ["i'm",
#   'back',
#   'top',
#   'molar',
#   'extract',
#   'swolen',
#   'face',
#   'al',
#   'numb',
#   'tothache',
#   'sinus',
#   'pain'],
#  ['finish',
#   '8',
#   'hour',
#   'texas',
#   'life',
#   'insurance',
#   'ce',
#   'tonight',
#   '2',
#   'hour',
#   'go'],
#  ['anyone',
#   'know',
#   'god',
#   'rap',
#   'song',
#   'ned',
#   'make',
#   'rapfun',
#   'cd',
#   'idea',
#   'help'],
#  ['want', 'go', 'peru', 'sumer', 'ah', 'hopefuly', 'yesyesyes', 'mis'],
#  ['<name>', 'hapen', 'maid', 'quit'],
#  ["i'm",
#   'awake',
#   'anybody',
#   'else',
#   'awake',
#   'wish',
#   'live',
#   'u',
#   'since',
#   'al',
#   'fun',
#   'hapens',
#   "i'm",
#   'aslep'],
#  ["charle's",
#   'power',
#   'lol',
#   'damn',
#   'savemart',
#   'lose',
#   'power',
#   'could',
#   'buy',
#   'ber'],
#  ['<name>', 'hehe', 'love', 'tired'],
#  ['mobile',
#   'phone',
#   'refuse',
#   'charge',
#   'either',
#   'batery',
#   'break',
#   'charger',
#   'bo'],
#  ['<name>',
#   'oh',
#   'wish',
#   'would',
#   'get',
#   'sign',
#   'something',
#   'send',
#   'let',
#   'cal',
#   'meet',
#   'something'],
#  ['<name>',
#   'hm',
#   'think',
#   'u',
#   'sleping',
#   'bad',
#   "can't",
#   'se',
#   'video',
#   'tomorow',
#   'night'],
#  ['morning',
#   'everyone',
#   'sory',
#   'go',
#   'early',
#   'last',
#   'night',
#   'bad',
#   'news',
#   'felt',
#   'totaly',
#   'crap',
#   'today',
#   'new',
#   'day'],
#  ['go', 'beach', 'start', 'rain'],
#  ['wish',
#   'parent',
#   'put',
#   'chinese',
#   'schol',
#   'young',
#   "it'l",
#   'much',
#   'easy',
#   'get',
#   'job'],
#  ['<name>',
#   '<name>',
#   'yeah',
#   'physicaly',
#   'move',
#   'aparently',
#   "we'l",
#   'report',
#   'directly',
#   'mr',
#   'hayward'],
#  ['<name>', 'airport', 'didnt', 'show', 'tonight', 'homo'],
#  ['<name>', 'jealous', 'loks', 'like', "schindler's", 'list', 'toronto'],
#  ['want', 'another', 'tat'],
#  ['<name>', 'come', 'erock', 'leave', 'bah'],
#  ['ned', 'make', 'lot', 'money', 'tomorow'],
#  ['<name>', 'rom', 'make', 'sad'],
#  ['nearly',
#   'fel',
#   'aslep',
#   'jolt',
#   'bed',
#   'masive',
#   'panic',
#   'atack',
#   "i'm",
#   'sure',
#   'slep',
#   'al'],
#  ['gay', 'make', '20', 'tonight'],
#  ['<name>',
#   'oh',
#   'anger',
#   'completely',
#   'forget',
#   'thirsty',
#   'thursday',
#   'oh',
#   'gaga',
#   'suck'],
#  ['one',
#   'people',
#   'wrong',
#   'world',
#   'blame',
#   'al',
#   'people',
#   'great',
#   'world',
#   'live',
#   'shit'],
#  ['<name>', 'nope', 'al', 'sleping', 'cuz', 'live', 'east', 'coast'],
#  ['<name>',
#   'bet',
#   'col',
#   'sr',
#   'huh',
#   'stop',
#   'sweat',
#   'since',
#   'non',
#   'dad',
#   'pack'],
#  ['<name>', 'ew', 'dislike'],
#  ['tactical',
#   'mistake',
#   'go',
#   'city',
#   'library',
#   'buying',
#   'milk',
#   'know',
#   'ouch',
#   'maybe',
#   'god',
#   'thing',
#   'try',
#   'uni'],
#  ['decide',
#   '2',
#   'trans',
#   'frm',
#   'relax',
#   '2',
#   'natural',
#   'hair',
#   'wish',
#   'whole',
#   'head',
#   'loked',
#   'like',
#   'rots',
#   'age',
#   'instant',
#   'gratification'],
#  ['<name>', 'sory', 'bout', 'cat'],
#  ['neds', 'increase', 'salary'],
#  ['stomach', 'fels', 'like', 'touch', 'ground', "i'm", 'ful'],
#  ['pug', 'wake', 'incredible', 'slep'],
#  ['<name>',
#   'cant',
#   'wait',
#   'hear',
#   'new',
#   'album',
#   'im',
#   'sure',
#   'wil',
#   'amazing',
#   'please',
#   'replay',
#   'love',
#   'much'],
#  ['much', 'work', 'litle', 'time'],
#  ['mised', 'iron', 'chef'],
#  ['<name>', 'ds', 'version', 'suck'],
#  ['bad', 'day'],
#  ['<name>',
#   'know',
#   'ridiculous',
#   'never',
#   'get',
#   'hang',
#   'love',
#   'chicago',
#   'want',
#   'go',
#   'shop',
#   'trip',
#   'sound',
#   'like',
#   'fun'],
#  ['hat', 'net', 'ayaw', 'bumukas', 'ng', 'twiter'],
#  ['ugh', 'internet'],
#  ['omg', 'didnt', 'twet', 'al', 'much', 'today', 'sadnes'],
#  ['feling', 'gidy', 'wana', 'go', 'home'],
#  ['wek', 'wasnt', 'without', 'adam', 'lambert', 'performance'],
#  ['<name>', 'link', 'work'],
#  ['pack', 'last', 'day', 'youth', 'camp'],
#  ['gosip', 'girl', 'come', 'back', 'chace'],
#  ['smh', 'hiphop', 'nursery', 'rhyme'],
#  ['somebody', 'please', 'save', 'polar', 'bear'],
#  ['<name>', 'lok', 'lot', 'picture', 'lol'],
#  ['<name>', 'realy', 'slepy', 'bore', 'right', 'word', 'much', 'work'],
#  ['come',
#   'atention',
#   '16yo',
#   'friend',
#   "i've",
#   'recently',
#   'gain',
#   'ton',
#   'weight',
#   'know'],
#  ['gues', 'im', 'stay', 'home', 'tonight', 'movieing'],
#  ['go', 'cd', 'store', 'search', 'cd'],
#  ['<name>',
#   'remind',
#   'weather',
#   'month',
#   'ago',
#   'horible',
#   'hope',
#   'al',
#   'wel',
#   'hug'],
#  ['mis', 'mom', 'quotmay', 'angel', 'lead', 'inquot'],
#  ["there's", 'realy', 'android', 'twiter', 'ap', "twetie's", 'calibre'],
#  ['jacksonvile',
#   'beach',
#   'walking',
#   'cold',
#   'water',
#   'work',
#   'morning',
#   'ily',
#   "lt''gt"],
#  ['<name>'],
#  ['<name>', 'fel', 'way', 'every', 'day'],
#  ["can't",
#   'slep',
#   'suck',
#   'one',
#   'day',
#   'slep',
#   'get',
#   'go',
#   'shop',
#   'mom',
#   'ugh'],
#  ['<name>',
#   'wel',
#   'get',
#   'home',
#   'til',
#   'tmw',
#   '530p',
#   'comcast',
#   'right',
#   'didnt',
#   'mi'],
#  ['slepytime', 'realy', 'mising', 'godfather', 'right', 'love', 'wayne'],
#  ['headache', 'right', 'suck'],
#  ['<name>', 'hope', 'ya', 'slepin', 'wel', 'guy', 'stil'],
#  ['finish', "i'm", 'color', 'drawing', 'come'],
#  ['<name>',
#   'lakers',
#   'baby',
#   'lakers',
#   "i'l",
#   'mis',
#   'game',
#   'tmwr',
#   'work',
#   "you'l",
#   'kep',
#   'posted',
#   'please'],
#  ['comfort', 'fod', 'day', 'pan', 'though', 'didnt', 'taste', 'god'],
#  ['damn', 'drunk', 'hot', 'suck'],
#  ['mises', 'baby'],
#  ['sleping', 'paperwork'],
#  ['shower',
#   'icecold',
#   'water',
#   'sweat',
#   'mean',
#   'one',
#   'thing',
#   "i'm",
#   'sick'],
#  ['midnight', 'cry', 'wish', 'person', 'want', 'right'],
#  ['<name>', "i'ma", 'ned', 'folow', 'real', 'quick', 'cause', "can't", 'dm'],
#  ["i'm", 'porly', "can't", 'slep'],
#  ['go',
#   'pole',
#   'clas',
#   'feling',
#   'discourage',
#   'hopeles',
#   'con',
#   'dance',
#   'sexy',
#   'move',
#   'spread',
#   'leg'],
#  ['<name>', 'por', 'unfortunate', 'soul', 'apear', 'pant', 'al'],
#  ['<name>',
#   '<name>',
#   'tell',
#   'often',
#   'wash',
#   'hair',
#   'would',
#   'never',
#   'speak'],
#  ['loks',
#   'like',
#   'another',
#   'sleples',
#   'night',
#   'dedicate',
#   'homework',
#   'sory',
#   'advance',
#   'm',
#   'chapman'],
#  ['<name>', 'u', 'lot', 'mock'],
#  ['didnt', 'say', 'godnight'],
#  ['<name>', 'pusy', 'damnit', 'send', 'email', 'right', 'btw'],
#  ['work', 'tom'],
#  ['hongkong',
#   'international',
#   'airport',
#   'wait',
#   '34',
#   'hour',
#   'next',
#   'flight',
#   'cebu'],
#  ["can't", 'slep', 'nothing', 'tv'],
#  ['pic',
#   'upload',
#   'baby',
#   'pic',
#   'cat',
#   'misy',
#   'adult',
#   'prety',
#   'litle',
#   'kity',
#   'baty',
#   'kiten',
#   'heaven'],
#  ['<name>', 'oh', 'ben', 'supersede', 'god', 'enough'],
#  ['today',
#   'say',
#   'godbye',
#   'second',
#   'god',
#   'friend',
#   'wek',
#   'dmp',
#   'least',
#   'sun',
#   'shin',
#   "i'm",
#   'definately',
#   'work',
#   'pm'],
#  ["fuckin'm", 'transtelecom'],
#  ['realy', 'bore', 'gues', 'wil', 'go', 'bed'],
#  ['<name>', 'meet', 'stranger', '10', 'min', 'ago', 'stalk', 'store'],
#  ['<name>', 'te', 'befin', 'u', 'suposed', 'leavin'],
#  ['sometimes',
#   'thing',
#   'say',
#   'hurt',
#   'one',
#   'love',
#   'unintentionaly',
#   'never',
#   'ever',
#   'take',
#   'back',
#   'fix'],
#  ['<name>', 'suck'],
#  ['<name>', 'know', 'mean'],
#  ['fever', 'dont', 'fel', 'work'],
#  ['take', 'horse', 'pils', 'hop', 'get', 'slep', 'tonight'],
#  ['<name>',
#   'pgpm',
#   'student',
#   'pgpm',
#   'student',
#   '4',
#   'year',
#   'back',
#   'wish',
#   'could',
#   'stay',
#   'one'],
#  ['mising', '<name>', '6', 'day', "can't", 'pas', 'quick', 'enough'],
#  ['<name>', 'hey', "that's", 'schol', 'hate', 'place'],
#  ['work',
#   'home',
#   'today',
#   'back',
#   'kiling',
#   'doctor',
#   'physio',
#   'later',
#   'today'],
#  ['back', 'work', 'distraction'],
#  ['<name>', 'demi', 'say', 'hi', 'enough', 'replay', 'please', 'love', 'much'],
#  ['never', 'notice'],
#  ['<name>',
#   'suck',
#   'wel',
#   'state',
#   'start',
#   'tomorow',
#   'im',
#   'headin',
#   '2',
#   'bed',
#   'nitey',
#   'nite'],
#  ['loks', 'like', 'go', 'nice', 'work', 'today', 'anoying', 'choice'],
#  ['<name>', 'guy', 'kep', 'set', 'list', 'forget', 'ask', 'one', 'x'],
#  ['first',
#   'impresion',
#   'silverlight',
#   'sadly',
#   'base',
#   'saw',
#   'today',
#   'quite',
#   'problematic'],
#  ['desperatly', 'hop', 'dad', 'take', "vanesa's", 'game'],
#  ['<name>', 'hi', 'fuck', 'job'],
#  ['mising', 'al', 'deply'],
#  ['time', 'go', 'bed', 'get', 'go', 'work'],
#  ['<name>',
#   'big',
#   'vanesa',
#   'go',
#   '3',
#   'september',
#   'go',
#   'fast',
#   'hard',
#   'cuz',
#   'im',
#   'workin',
#   'much',
#   'mis',
#   'alot'],
#  ['<name>',
#   'snif',
#   'take',
#   'care',
#   'ravel',
#   'hopefuly',
#   "we'l",
#   'chat',
#   'son',
#   'mean',
#   'time',
#   "i'l",
#   'hela',
#   'mi'],
#  ['<name>', 'lucky', 'want', 'teleport'],
#  ['somebody', 'please', 'save', 'polar', 'bear'],
#  ['nose',
#   'runy',
#   'head',
#   'pound',
#   'teth',
#   'hurt',
#   'like',
#   'bitch',
#   'man',
#   'fel',
#   'awful'],
#  ['want', 'leave'],
#  ['headin',
#   'home',
#   'refresh',
#   'mind',
#   'soul',
#   'justa',
#   'lil',
#   'bit',
#   'bac',
#   'reality'],
#  ['god',
#   'lord',
#   'sen',
#   'agency',
#   'work',
#   'upcoming',
#   'open',
#   'day',
#   'money',
#   'jam'],
#  ['wut'],
#  ['work', 'friday'],
#  ['grove', 'drag', 'hel', 'hope', 'suck'],
#  ['<name>',
#   'fel',
#   'like',
#   'shit',
#   'say',
#   'hapy',
#   'belated',
#   'birfday',
#   "i'm",
#   'month',
#   'late'],
#  ['<name>',
#   'lmao',
#   'thats',
#   'sad',
#   'kinda',
#   'discourage',
#   '4rom',
#   'goin',
#   "shit's",
#   'wack'],
#  ['get',
#   'home',
#   'work',
#   '945',
#   'finish',
#   'cleaning',
#   'ned',
#   'eat',
#   'diner',
#   'know',
#   'want',
#   'ugh',
#   'oh',
#   'wel',
#   'might',
#   'eat'],
#  ['<name>', 'wish'],
#  ['mis',
#   'litle',
#   'baty',
#   '3',
#   'month',
#   'old',
#   'get',
#   'sick',
#   'always',
#   'fun',
#   'ful',
#   'life',
#   'lt3',
#   'even',
#   'end'],
#  ['fc', 'finaly', 'time', 'hate', 'keps', 'hapening'],
#  ['seriously', 'bore', 'without', 'anyone', 'talk', 'tired', 'enough', 'slep'],
#  ['morning', 'hate', 'morning', 'ofensive'],
#  ['<name>', 'stil', 'give', 'computer', 'break', 'omg'],
#  ['bed',
#   '<name>',
#   'never',
#   'answer',
#   'text',
#   'anymore',
#   'thought',
#   'day',
#   'send',
#   'one',
#   'never',
#   'hear',
#   'back',
#   'sad',
#   'day'],
#  ['u'],
#  ['<name>', 'wah', "we're", 'longer', 'pep'],
#  ['<name>',
#   'lol',
#   'wow',
#   'dawg',
#   'sound',
#   'like',
#   'playing',
#   'fel',
#   'bad',
#   'haha'],
#  ['extremly', 'dep'],
#  ['litle',
#   'foster',
#   'kitens',
#   'get',
#   'big',
#   'chuba',
#   'winston',
#   'go',
#   '2',
#   'b',
#   'mised',
#   'get',
#   'amazing',
#   'home'],
#  ['one', 'wek', 'til', 'exam', 'block'],
#  ['<name>', "i'm", 'home', 'cat', 'right'],
#  ['hop', 'fail', 'english', 'would', 'sad'],
#  ['know',
#   'would',
#   'great',
#   'shoulder',
#   'stop',
#   'hurt',
#   'slep',
#   'normal',
#   'wantned',
#   'solid',
#   'hour',
#   'god',
#   'slep'],
#  ["leno's", 'last', 'show', 'tonight', 'like', 'beter', 'conan'],
#  ['<name>', "i'm", 'sory', 'bad', 'driving', 'experience'],
#  ['<name>'],
#  ['already', 'mises', '<name>'],
#  ['plan', 'may', 'change'],
#  ['sister', 'douchebag'],
#  ['<name>', "there's", 'relisting', 'fe', 'complete', 'sale', 'suck'],
#  ['<name>', 'random'],
#  ['know',
#   'wear',
#   'sars',
#   'mask',
#   'plane',
#   'socal',
#   'feling',
#   'beginings',
#   'sore',
#   'throat'],
#  ['gut',
#   'bathrom',
#   'stil',
#   'fre',
#   'early',
#   'work',
#   'go',
#   'hapen',
#   'ned',
#   'lo'],
#  ['<name>', 'july', 'long'],
#  ['<name>',
#   'aw',
#   'wish',
#   'could',
#   'ben',
#   "i'm",
#   'stuck',
#   'jab',
#   'eye',
#   'kniting',
#   'nedles'],
#  ['<name>', 'wonder', 'mnet', 'wil', 'show'],
#  ['wear', 'glases', 'give', 'headache'],
#  ['<name>',
#   'stop',
#   'talkin',
#   'fod',
#   'haha',
#   'fil',
#   'like',
#   'sum',
#   'nw',
#   'ha',
#   'hows',
#   'day',
#   'goin',
#   'start'],
#  ['finish',
#   'sew',
#   'night',
#   'upload',
#   'picture',
#   'slidebar',
#   'beach',
#   'cant',
#   'believe',
#   'dificulties',
#   'twiter'],
#  ['thank',
#   '<name>',
#   'cant',
#   'wait',
#   'um',
#   'btw',
#   'ima',
#   'crash',
#   'stil',
#   'sick'],
#  ['first', 'work', 'computer', 'home', 'laptop', 'fuck'],
#  ['liesgirlstel',
#   'guy',
#   'cals',
#   'phone',
#   'se',
#   'number',
#   'real',
#   'oh',
#   'phone',
#   'work',
#   'try',
#   'tomorow'],
#  ['ber',
#   'friday',
#   'melbourne',
#   'cbd',
#   'mtub',
#   'mini',
#   'cmon',
#   'thirsty',
#   'lonely',
#   'bugers',
#   'make',
#   'fel',
#   'like',
#   'scoty',
#   'mate'],
#  ['<name>',
#   'know',
#   'come',
#   'back',
#   '2',
#   '1st',
#   'lose',
#   'lead',
#   'last',
#   '6',
#   'minute'],
#  ['gosh',
#   'sumer',
#   'vacation',
#   'almost',
#   'philipines',
#   'kinda',
#   'sad',
#   'wonder',
#   'section',
#   'wil'],
#  ['<name>', '<name>', 'page', '6', 'm', 'twiterworld', '26', 'vote'],
#  ["i'm", 'bum', "can't", 'wear', 'swet', 'nike', 'kick', 'work'],
#  ['<name>', 'twiter', 'break'],
#  ['slep',
#   'god',
#   'night',
#   'tweties',
#   'oc',
#   'tomorow',
#   'hope',
#   'pray',
#   'rachyl',
#   'get',
#   'beter',
#   'son'],
#  ['<name>', 'depresing', "i'm", 'stick', 'inside', 'al', 'day'],
#  ['<name>',
#   'even',
#   'saw',
#   'news',
#   'fed',
#   'archie',
#   'website',
#   "can't",
#   'believe',
#   "he'd",
#   'chose',
#   'veronica',
#   "i'm",
#   'disapointed'],
#  ['hate', 'sick', 'mis', '<name>', '<name>', '<name>'],
#  ['<name>',
#   'im',
#   'eat',
#   'slider',
#   'barjohnys',
#   'theyre',
#   'pork',
#   'tho',
#   'bef',
#   'stil',
#   'search'],
#  ['get',
#   'ready',
#   'schol',
#   'second',
#   'math',
#   'test',
#   'today',
#   'also',
#   'last',
#   'day',
#   '3rd',
#   'year',
#   'next',
#   'wek',
#   'wil',
#   'oficialy',
#   '4th',
#   'year'],
#  ['wake', 'wana', 'stay', 'bed'],
#  ['depresed', 'include', 'morcom', 'garden', 'quiz', 'facebok'],
#  ['<name>',
#   'yeah',
#   'stil',
#   'totaly',
#   'high',
#   '60',
#   'notloking',
#   'forward',
#   'aug',
#   'sept'],
#  ['upsidedown', 'tomato', 'plant', 'die'],
#  ['dep', 'priecing', 'soul'],
#  ['<name>',
#   'oh',
#   'come',
#   'get',
#   'next',
#   'wek',
#   'get',
#   'next',
#   'wek',
#   'ful',
#   'exam'],
#  ['friday', 'last', 'much', 'fun', 'skint', 'though'],
#  ['<name>',
#   'know',
#   'tel',
#   'anyone',
#   'dont',
#   'know',
#   'dad',
#   'tell',
#   'famz',
#   'yet',
#   'think',
#   "i'm",
#   'take',
#   'online'],
#  ['<name>', "can't", 'iht', 'early', 'icant', 'wait', 'long', 'ahar'],
#  ['friday',
#   'yay',
#   'bonus',
#   'drive',
#   'wales',
#   'tonight',
#   'athough',
#   'wil',
#   'mi',
#   'kiten',
#   'cudles',
#   'go',
#   'ride'],
#  ['child',
#   'promise',
#   'birthday',
#   'brekie',
#   'bed',
#   "there's",
#   'problem',
#   "there's",
#   'buger',
#   'al',
#   'fod',
#   'house'],
#  ['<name>', 'wops', 'realize', 'dm', 'go'],
#  ['think', 'wil', 'able', 'get', 'bed', 'tomorow', 'morning', 'wil', 'se'],
#  ['cant', 'use', 'blackbery', 'today', 'suck'],
#  ['q',
#   'studio',
#   'create',
#   'open',
#   'season',
#   'gogle',
#   'lok',
#   'dvd',
#   'downstairs',
#   'feling',
#   'lazy'],
#  ['time', 'change'],
#  ['<name>', 'hate'],
#  ['time',
#   'tv',
#   'bed',
#   'spend',
#   'al',
#   'day',
#   'catch',
#   'study',
#   'hate',
#   'online',
#   'sumer',
#   'clases'],
#  ['<name>', 'video', 'available', 'u', 'foreigner'],
#  ['want', 'visit', 'animal', 'late'],
#  ['<name>', 'pc', 'agre', 'problem', 'must', 'stop', 'spending', 'work'],
#  ['jonaswebcast', 'mised'],
#  ['dang',
#   'realy',
#   'lok',
#   'like',
#   'crap',
#   'sigh',
#   '35mins',
#   'shower',
#   '10mins',
#   'get',
#   'ready'],
#  ['wait', 'get', 'pick'],
#  ['exhausted', "can't", 'slep', 'like', 'night'],
#  ["i'm",
#   'gona',
#   'mi',
#   'al',
#   'live',
#   'comet',
#   'action',
#   'tomorow',
#   'go',
#   'take',
# ...
#  ['say', 'morning', 'everyone', 'work', '10', "min's"],
#  ['bt',
#   'ben',
#   'gamer',
#   'like',
#   '2',
#   'year',
#   'make',
#   'atempt',
#   'lol',
#   'yea',
#   'luvd',
#   'f1',
#   'extent',
#   '<name>'],
#  ['4pm', 'friday', 'leave', '6am', 'thursday', 'surely'],
#  ['<name>',
#   "i'm",
#   'sory',
#   'ya',
#   'gota',
#   'let',
#   'know',
#   "i've",
#   'ben',
#   'boked',
#   'al',
#   'wek'],
#  ['<name>',
#   'hahaha',
#   'oh',
#   'man',
#   'please',
#   'come',
#   'pomona',
#   'would',
#   'love',
#   'se',
#   'everyday',
#   'instead',
#   'like',
#   'year'],
#  ['<name>', 'mis', 'come', 'michigan', 'like', "can't", 'wait', 'til', 'july'],
#  ['<name>', 'maybe', 'god', "night's", 'slep', 'everyone'],
#  ['far', 'pdhpe', 'asignment', 'due', 'next', 'wek', 'english', 'homework'],
#  ['forget', 'ace', 'card', 'carto', 'lazy', 'fetch'],
#  ['<name>', 'yea', 'tough', 'kep', 'go', 'sometimes', "i'm", 'sure', 'worth'],
#  ['<name>', 'disapointment', 'haha'],
#  ['<name>',
#   'hun',
#   'okay',
#   'se',
#   'alot',
#   'post',
#   'exercise',
#   'like',
#   'mad',
#   'eat',
#   'sleping'],
#  ['oh', 'twetdeck', 'malfunction', 'il', 'web', 'wil', 'fixd'],
#  ['<name>',
#   "i'm",
#   'sory',
#   'stil',
#   'sick',
#   'u',
#   'know',
#   'know',
#   'u',
#   'wil',
#   'gues',
#   'quotpelzer',
#   'presentquot'],
#  ['<name>',
#   'adam',
#   'samberg',
#   'new',
#   'mon',
#   'trailor',
#   'god',
#   'even',
#   'bad',
#   'cable',
#   'friday'],
#  ['<name>', 'hapened', "i'm", 'afraid', 'mised', 'large', 'part', 'story'],
#  ['work', '545am'],
#  ['<name>', 'hel', 'yes', "i'm", 'late'],
#  ['del',
#   'fx10',
#   'pcoverip',
#   'audio',
#   'device',
#   'teradici',
#   'give',
#   'hard',
#   'time',
#   'linux',
#   'ubuntu',
#   'jaunty',
#   'kernel',
#   'isnt',
#   'load',
#   'sndhdaintel',
#   'drv'],
#  ['get', 'kick', 'tripoly', 'lol', 'get', 'bad', 'card', 'suck'],
#  ['crepe',
#   'ice',
#   'cream',
#   'social',
#   'god',
#   'time',
#   'lars',
#   'real',
#   'girl',
#   'sad',
#   'movie'],
#  ['hot', 'huf'],
#  ['closenes', 'distance', 'closenes', 'everything', 'sems', 'distant'],
#  ['another', 'one', 'bite', 'dust'],
#  ['ah', 'quotlet', 'right', 'one', 'inquot', 'dvd', 'break'],
#  ['<name>',
#   'hey',
#   'love',
#   'ac',
#   'se',
#   'online',
#   'yet',
#   'cant',
#   'wait',
#   'buy',
#   'lok',
#   'amaze'],
#  ['<name>', 'thought', 'dwel', 'certain', 'person'],
#  ['fml', 'work', 'uniform', 'washing', 'line'],
#  ['oh', 'shit', 'realize', 'stil', 'talk', 'b', 'like', 'dat', 'time'],
#  ['42nd',
#   'writen',
#   'fuck',
#   'get',
#   'le',
#   'idea',
#   'every',
#   'day',
#   'every',
#   'day'],
#  ['<name>', 'naw', 'doesnt', 'match', 'lol', 'shenanigan', 'discus', 'thing'],
#  ['<name>', 'part', 'unfortunately'],
#  ['<name>',
#   'dude',
#   'know',
#   'personal',
#   'experience',
#   'sory',
#   'something',
#   'like',
#   'go'],
#  ['<name>',
#   'aw',
#   'wel',
#   'randomly',
#   'wake',
#   "can't",
#   'slep',
#   'many',
#   'thing',
#   'mind'],
#  ['<name>', 'baby', 'mi'],
#  ['<name>', 'since', 'obviously', 'live', 'alaska', 'radio', 'station', 'get'],
#  ['murder', 'two', 'fucking', 'mouse', 'cant', 'slep'],
#  ['oh', 'no', 'hey', "what's", 'tato', 'say'],
#  ['<name>', 'vcr'],
#  ['<name>', 'wish', 'could', 'time', 'xbox', 'project', 'al', 'tie'],
#  ['al', 'pancake', 'always', 'end', 'sogy'],
#  ['4',
#   'big',
#   'zongzi',
#   'lunch',
#   'eat',
#   'work',
#   'work',
#   'le',
#   'eat',
#   'wh',
#   'useles',
#   'become'],
#  ['sososo', 'bum', 'like', 'realy', 'bum', 'hate', 'rain', 'ruin', 'date'],
#  ['work',
#   'late',
#   'night',
#   'del',
#   'notebok',
#   "del's",
#   'quality',
#   'go',
#   'hil',
#   'warenty',
#   'service',
#   'suck',
#   'por',
#   'people',
#   'buy',
#   'mac',
#   'instead'],
#  ['wow', 'hurt', 'way', 'bad', 'think', 'would'],
#  ['none', 'thought', 'make', 'sense', "i'm", 'sober'],
#  ['<name>', 'know', 'right', 'hopefuly', 'something', 'come', 'though'],
#  ['cant', 'slep', 'tomorow', 'must', 'wake', 'early'],
#  ['<name>',
#   'body',
#   'already',
#   'develop',
#   'mind',
#   'mind',
#   'refuse',
#   'cooperate',
#   'set',
#   'schedule'],
#  ['<name>',
#   'suposed',
#   'back',
#   'sun',
#   'via',
#   'private',
#   'jet',
#   'btw',
#   'mite',
#   'hav',
#   'stay',
#   'bymyself',
#   'thnk',
#   'god',
#   'another',
#   'wek',
#   'amp',
#   'want',
#   'bruno'],
#  ['trash', 'repops', 'get', 'tomorow', 'night', 'supose'],
#  ['nursing',
#   'bruise',
#   'motorbike',
#   'crash',
#   'wednesday',
#   'night',
#   'leave',
#   'london',
#   'workplace',
#   'ground',
#   'much',
#   'hard',
#   'old',
#   'get'],
#  ['bored', 'headache'],
#  ['huge', 'headache', 'godnight'],
#  ['fels',
#   'like',
#   'crap',
#   'whenever',
#   'lay',
#   '<name>',
#   'hate',
#   'heartburn',
#   'amp',
#   'backache'],
#  ['<name>', 'mis', 'lonely', 'empty', 'without'],
#  ['<name>',
#   'noice',
#   'realise',
#   'exam',
#   '2',
#   'weks',
#   'forget',
#   'whole',
#   '2',
#   'weks',
#   'unit',
#   '4',
#   'term',
#   '2',
#   'thing'],
#  ['justwatched',
#   'like',
#   '5',
#   'straight',
#   'episode',
#   'escape',
#   'id',
#   'discovery',
#   'chanel',
#   'guy',
#   'imprison',
#   '6',
#   'woman',
#   'kiled',
#   '2',
#   'coke'],
#  ['mising', 'everyone'],
#  ['go', 'bed', 'age', 'ago', 'damn', 'tedtalks', 'gota', 'get', 'early'],
#  ['0', '2', 'give', '3', 'point'],
#  ['<name>',
#   'make',
#   'pork',
#   'product',
#   "they've",
#   'fuck',
#   'stoped',
#   'import',
#   'dubai',
#   'bad',
#   'time'],
#  ['another', 'build', 'fail', 'something', 'right', 'big', 'scheme', 'thing'],
#  ['wife', 'tok', 'last', '20', 'mcdonalds', 'breakfast', 'today'],
#  ['wish', 'go', 'love', 'sound'],
#  ['siser',
#   'move',
#   'tomorow',
#   'make',
#   'sad',
#   'actualy',
#   'gues',
#   'technicaly',
#   'couple',
#   'hour',
#   'since',
#   'already',
#   'friday'],
#  ['kep', 'faling', 'aslep', "i'm", 'supose', 'awake', 'mis', 'baby'],
#  ['<name>'],
#  ['way', 'notingham', 'want', 'go'],
#  ['churchil', 'down', 'tomorow'],
#  ['chicago', 'ride', 'caling', 'back'],
#  ['k',
#   'godnight',
#   'gota',
#   'chuck',
#   'e',
#   'chese',
#   'tomorow',
#   'folowing',
#   'kindergarten',
#   'shot',
#   'physical',
#   'bla'],
#  ['ned',
#   'wake',
#   'earlier',
#   "i'm",
#   'actualy',
#   'tire',
#   'enough',
#   'fal',
#   'aslep'],
#  ['bah', 'police', 'end', 'party', '5', 'start'],
#  ["i've", 'get', 'catch', 'bus', 'work'],
#  ['<name>', 'sad'],
#  ['<name>', 'omg', 'never', 'sen', 'ring', 'crepy', 'movie'],
#  ['man', '<name>', 'get', 'iphone', 'im', 'jealous'],
#  ['<name>', 'funy', 'u', 'havent', 'show', 'love', 'yet', 'al'],
#  ['<name>', 'absolutely', 'nothin'],
#  ['<name>',
#   'luv',
#   'ur',
#   'admit',
#   'niley',
#   'ki',
#   'change',
#   'mind',
#   'haha',
#   'amp',
#   'demisterling',
#   'jemi',
#   'stil',
#   'cute'],
#  ['<name>',
#   'make',
#   'fel',
#   'beter',
#   'lose',
#   '10',
#   'overnight',
#   'cause',
#   'post',
#   'picture',
#   'baby'],
#  ['stil', 'sick', 'sigh'],
#  ['<name>',
#   'oh',
#   'por',
#   'beth',
#   'friend',
#   "i'm",
#   'naughty',
#   "i'm",
#   'unperfect'],
#  ['josh',
#   'caled',
#   'big',
#   'bucket',
#   'ugly',
#   'wish',
#   'luck',
#   'audition',
#   'twets'],
#  ['fel', 'realy', 'weird'],
#  ['<name>', "i'm", 'try', 'self', 'learn', 'photoshop', 'go', 'wel'],
#  ['<name>',
#   'ever',
#   'sen',
#   'tv',
#   'show',
#   'dead',
#   'like',
#   'die',
#   'become',
#   'grim',
#   'reaper',
#   'take',
#   "people's",
#   'soul',
#   'acidents'],
#  ['<name>', "i'm", 'sory', "i'm", 'think', 'hope', 'wek', 'get', 'beter'],
#  ['steam',
#   'punlk',
#   'fashion',
#   'show',
#   'anime',
#   'north',
#   'first',
#   'year',
#   'since',
#   'torcon',
#   'back',
#   'til',
#   '<name>',
#   'amp',
#   'mised'],
#  ['throat', 'hurt', 'gona', 'go', 'read', 'go', 'bed', 'text'],
#  ['die', 'hangout', 'friday', 'afternon'],
#  ['eh', 'cold'],
#  ['man', '<name>', 'get', 'iphone', 'im', 'jealous'],
#  ['fjdskal', 'im', 'realy', 'frustrate'],
#  ['<name>', 'aw', 'youtubed'],
#  ['wonder', 'come', 'mcdonalds', 'take', 'long', 'deliver', 'fod'],
#  ['<name>',
#   'ya',
#   'weather',
#   'ben',
#   'super',
#   'weird',
#   'loked',
#   'like',
#   'gona',
#   'rain',
#   'today',
#   'course',
#   'darnit'],
#  ['<name>',
#   'much',
#   'injustice',
#   'imagine',
#   'wil',
#   'get',
#   'bad',
#   'get',
#   'beter',
#   'afraid',
#   'doubt',
#   'sory'],
#  ['wil', 'mi', 'nostalgia', 'everyone', 'please', 'kick', 'tushar'],
#  ["i'm", 'kind', 'sick', 'n', 'tire', 'b', 'guy', 'dish'],
#  ['clas',
#   'color',
#   'day',
#   'tomorow',
#   'last',
#   'time',
#   'lot',
#   'remember',
#   'tomorow',
#   'bet',
#   "i'l",
#   'forget'],
#  ['<name>',
#   'idk',
#   'lol',
#   'head',
#   'hurt',
#   'rly',
#   'bad',
#   'amp',
#   'stomach',
#   'hm',
#   'personaly',
#   'think',
#   'al',
#   'ive',
#   '2',
#   'deal',
#   'wit'],
#  ['<name>', '<name>', 'expensive'],
#  ['wtf',
#   'facebok',
#   'clear',
#   'whole',
#   'survey',
#   'last',
#   'q',
#   'night',
#   'get',
#   'beter',
#   'beter',
#   'else',
#   'next'],
#  ['say', 'god', 'say', 'bad', 'afternon'],
#  ['say', "i've", 'get', 'number', '10', 'geting', 'low'],
#  ['mises', 'twitastic', 'fwiends'],
#  ['<name>', 'take', 'advice', 'lokin', 'phone', 'cost', 'relationship'],
#  ['play', 'stret', 'fighter', 'iv', 'seth', 'rap'],
#  ['weird', "guy's", 'house', 'without', 'like'],
#  ['fuck',
#   'waste',
#   'deodorant',
#   'aint',
#   'goin',
#   'aint',
#   'havin',
#   'company',
#   'let',
#   'funk',
#   'ya'],
#  ['<name>', 'wish', 'know', 'curse', 'tumblr'],
#  ['beautiful', 'day', 'shame', "i've", 'get', 'spend', 'ofice'],
#  ['come',
#   'q',
#   'quotany',
#   'recomended',
#   'hairdreser',
#   'u',
#   'r',
#   'ful',
#   'sugested',
#   'others',
#   'quot',
#   'ego',
#   'talk',
#   "i'm",
#   'line'],
#  ['busines', 'exam', 'tomorow'],
#  ['<name>', 'oh', 'know', 'budgeting'],
#  ['finish',
#   'watch',
#   'series',
#   'return',
#   'chaser',
#   'war',
#   'everything',
#   'realy',
#   'quite',
#   'crap',
#   'compare',
#   'use'],
#  ['wow',
#   'realize',
#   'check',
#   'twiter',
#   'since',
#   '9am',
#   'saw',
#   'todo',
#   'list',
#   'god',
#   'news',
#   'get',
#   'lot',
#   'do',
#   'bad',
#   "newsdon't",
#   'know',
#   'day',
#   'go'],
#  ['mis', 'bestfriend', 'leave', 'schol'],
#  ['ouch', 'earphone', 'shock'],
#  ['<name>', "i'm", 'try', 'slep', 'work'],
#  ['tumy', 'hurt'],
#  ['back', 'grimsby', 'suck', 'bein', 'back', 'amazin', 'wknd', 'anyway'],
#  ['fareweling', 'employe', 'tonight'],
#  ['<name>',
#   'haha',
#   '18',
#   'ive',
#   'get',
#   'one',
#   'go',
#   'curse',
#   'none',
#   'friend',
#   'like',
#   'tai',
#   'lol'],
#  ['gorgeous', 'weather', 'bike'],
#  ['morning',
#   'al',
#   'water',
#   "heating's",
#   'pack',
#   "can't",
#   'bath',
#   'realy',
#   'want',
#   'bath'],
#  ['<name>', 'girl', 'confuse'],
#  ['lyricalyme', 'would'],
#  ['<name>', 'se', 'u', 'comin', '4', 'city', 'u', 'comin', '4'],
#  ['blackout', 'city', 'never', 'god'],
#  ['<name>', 'aw', 'maybe', 'traumatize'],
#  ['<name>',
#   'flight',
#   'already',
#   'boked',
#   'plus',
#   'gd2',
#   '1st',
#   'birthday',
#   "can't",
#   'mis',
#   'especialy',
#   'mised',
#   'gd1'],
#  ['<name>',
#   'live',
#   'al',
#   'smal',
#   'market',
#   'deliver',
#   'dayold',
#   'bread',
#   'fod',
#   'bank',
#   'time',
#   'realy',
#   'tough',
#   'even'],
#  ['drink',
#   'hickups',
#   'prety',
#   'lay',
#   'back',
#   'great',
#   'night',
#   'stil',
#   "can't",
#   'help',
#   'mad',
#   'situation',
#   'put'],
#  ['think',
#   'take',
#   'medicine',
#   'cuz',
#   'laugh',
#   'hard',
#   'head',
#   'much',
#   'pain',
#   'think',
#   'laughter',
#   'gud'],
#  ['ugh', 'much', 'hapened', 'today', 'realy', 'ned', 'hug'],
#  ['bore', 'wana', 'go', 'taekwando'],
#  ['watch', 'leno', 'second', 'last', 'time', 'tonight', 'show'],
#  ['<name>', 'ur', 'pic', 'go'],
#  ['tongue', 'stil', 'hurt', 'ned', 'slep'],
#  ['twiter'],
#  ['<name>',
#   'chris',
#   'stay',
#   'glasgow',
#   'instead',
#   'cause',
#   'absolutely',
#   'acomodation',
#   'edinburgh',
#   'due',
#   'marathon'],
#  ["can't",
#   'wait',
#   'til',
#   'sunday',
#   'new',
#   'episode',
#   'supernatural',
#   '6',
#   'episode',
#   'leave'],
#  ['<name>', 'aw', 'ok', 'lol', 'hopefuly', 'im', 'stil', 'back', 'state'],
#  ['<name>', 'sad', 'twets', 'sad'],
#  ['neds', 'litle', 'lie', 'feling', 'great', 'today', 'bo'],
#  ['<name>',
#   'workplace',
#   'shortsleved',
#   'shirt',
#   'absolutely',
#   'necesary',
#   'today'],
#  ['decide', "can't", 'stand', '<name>', 'altop', 'spam', 'long'],
#  ['al', 'anal', 'sex', 'forget', 'lube', 'damn', 'may', 'ned', 'go', 'e', 'r'],
#  ['playn', 'maden', 'austin', 'im', 'go', 'mis'],
#  ['mis', 'rich'],
#  ['headache', 'century', 'come', 'fel', 'fuck'],
#  ['disapointed',
#   'know',
#   'get',
#   'silver',
#   'award',
#   'want',
#   'gold',
#   'award',
#   'hate',
#   'second',
#   'best'],
#  ['please',
#   'make',
#   'livechat',
#   'saturday',
#   'cu',
#   'go',
#   'schol',
#   'wekdays',
#   '56',
#   '<name>'],
#  ['want',
#   'go',
#   'back',
#   'bed',
#   'child',
#   'lok',
#   'may',
#   'slep',
#   'al',
#   'sunday',
#   'enevitable',
#   'hangover',
#   'may',
#   'require'],
#  ['get', 'mad', 'tire', 'sex', 'slepytime', 'night'],
#  ['twiter', 'shit', 'bore', 'c', 'ben', 'month'],
#  ['anyone',
#   'know',
#   'convert',
#   '6',
#   'est',
#   'aus',
#   'time',
#   'rofl',
#   'xd',
#   'fuck',
#   'radio',
#   'disney'],
#  ['home',
#   'ice',
#   'cream',
#   'twetup',
#   'first',
#   'twetup',
#   'pic',
#   'camera',
#   'batery',
#   'die',
#   'last',
#   'night',
#   'forget',
#   'charge'],
#  ['<name>',
#   'ok',
#   "that's",
#   'subtly',
#   'say',
#   "i'm",
#   'longer',
#   'fave',
#   'teme',
#   '1',
#   'thing',
#   'firangs',
#   'steal',
#   'vocab',
#   'ur',
#   'eating',
#   'word'],
#  ['<name>', 'bye', 'scoty', "i'm", 'gona', 'mi', 'ilylt', '3'],
#  ['new', 'coment', 'jowki', 'wish', 'time', 'blog', 'often'],
#  ['get', 'temporary', 'tato', 'would', 'totaly', 'sad', 'die'],
#  ['<name>', 'gray', 'fel', 'neglected'],
#  ['<name>',
#   'oh',
#   'know',
#   'fel',
#   'damn',
#   'representative',
#   'bank',
#   'america',
#   'try',
#   'make',
#   'sound',
#   'like',
#   'b'],
#  ['tire', 'cold', 'runy'],
#  ['<name>',
#   'dun',
#   'wana',
#   'travel',
#   'al',
#   'way',
#   'lunch',
#   'yeah',
#   'ben',
#   'nice',
#   'place',
#   'mising',
#   'shanepunjab',
#   'though'],
#  ['ma',
#   'cleanout',
#   'rom',
#   'rearanging',
#   'send',
#   'mother',
#   'buy',
#   'bin',
#   'bokshelf',
#   'since',
#   'mine',
#   'suck',
#   'bad',
#   'mod'],
#  ['<name>', 'rob', 'get', 'lucky', 'game', 'beat', '209205'],
#  ['feling',
#   'realy',
#   'sick',
#   'watch',
#   'fifth',
#   'element',
#   'smoke',
#   'cig',
#   'ugh',
#   'hate',
#   'cold'],
#  ['bah', 'think', '<name>', 'fb', 'fan', 'page', 'wil', 'get', '750'],
#  ['someone', 'save', 'dont', 'want', 'pack', 'anymore'],
#  ['home', 'schol', 'shitest', 'day', 'today'],
#  ['<name>',
#   'swety',
#   'sit',
#   'table',
#   'morning',
#   'wake',
#   'swet',
#   'oh',
#   'btw',
#   'think',
#   "i'l",
#   'home',
#   'around',
#   '7',
#   'pm',
#   'xx'],
#  ['bruise', 'kne', 'wil', 'make', 'hard', 'skate', 'tomorow'],
#  ['<name>',
#   'lol',
#   'go',
#   'buy',
#   'new',
#   'laptop',
#   'feb',
#   'already',
#   'know',
#   'lol',
#   'loked',
#   'anyway',
#   'walk',
#   'away',
#   'sadfaced'],
#  ['fyi',
#   'internet',
#   'thurstag',
#   'saturday',
#   'feling',
#   'wil',
#   'become',
#   '80x',
#   'productive',
#   'day'],
#  ['sit', 'everyone', 'tok', 'god', 'seat'],
#  ['fre', 'wifi', 'vacay', 'ruin'],
#  ['<name>', 'ah', 'wel', 'least', "i'm"],
#  ['<name>',
#   'mat',
#   'havent',
#   'speak',
#   'age',
#   'dude',
#   'dont',
#   'forget',
#   'bout',
#   'ur',
#   'ausie',
#   'fan',
#   'lol',
#   'love',
#   'ya',
#   'x'],
#  ['<name>', 'oh', 'wait', 'wrong', 'state'],
#  ['fuck', 'cold', 'north', 'like', '7', 'df', 'yesterday', '37,4'],
#  ['u',
#   'mising',
#   'ur',
#   'frnds',
#   'hear',
#   'quotmanaselam',
#   'quot',
#   'kulir',
#   '10',
#   'degre',
#   'movie',
#   'amazing',
#   'nanbargale',
#   'mis',
#   'u',
#   'guy'],
#  ['try',
#   'slep',
#   'without',
#   'pils',
#   'work',
#   '3am',
#   'wide',
#   'awake',
#   'late',
#   'take',
#   "i'l",
#   'slep',
#   'til',
#   '3pm'],
#  ['phone', 'wil', 'die', 'son', 'oh'],
#  ['sory', 'mean'],
#  ['forget', 'power', 'cable', 'home', 'today'],
#  ['dog',
#   'eye',
#   'sem',
#   'bad',
#   'fork',
#   'new',
#   'wash',
#   'machine',
#   'vet',
#   'bil',
#   'top',
#   'eh'],
#  ["can't",
#   'slep',
#   "can't",
#   'find',
#   "grandmother's",
#   'quilt',
#   'locket',
#   "i'm",
#   'sick',
#   'cause',
#   'may',
#   'lose',
#   'somehow',
#   'steal'],
#  ['<name>', 'think', 'go', 'se', 'pic', 'clean', 'car'],
#  ['<name>',
#   'want',
#   'im',
#   '18',
#   'tampc',
#   'say',
#   '18',
#   'wana',
#   'make',
#   'exception'],
#  ['<name>',
#   'amazing',
#   'thing',
#   'keping',
#   'al',
#   'online',
#   'conversation',
#   'one',
#   'place',
#   'unfortunately',
#   'place',
#   'gogle'],
#  ['<name>', 'sory', 'spanish', 'moment'],
#  ['<name>', 'yay', 'thats', 'sp', 'far', 'away'],
#  ['must', 'clear', 'dvr', 'get', 'rid', 'tomorw'],
#  ['bum', 'f', 'break'],
#  ['sign', 'acount', 'political', 'website', 'could', 'post', 'coment', 'work'],
#  ['come', 'never', 'slep', 'past', 'god'],
#  ...]

# %% [markdown]
# ### Tokenization

# %%
"""
li1 = []
for x in li:
    li1.append(x.split())
"""

# %% [markdown]
# ### NER (Name Entity Recognition)

# %%
import spacy 
  
nlp = spacy.load('en_core_web_sm') 
  
sentence = "I loved trip to paris with john, but now i miss him"
  
doc = nlp(sentence) 
for ent in doc.ents: 
    sentence = sentence.replace(ent.text,'['+ent.label_+']')
sentence
# Out:
# 'I loved trip to [GPE] with [PERSON], but now i miss him'

# %%
li1 = lii

# %%
import spacy
from spacy.tokenizer import Tokenizer
from spacy.util import compile_infix_regex

nlp = spacy.load("en_core_web_sm")

li2 =[]
def ner(li):
    for i in li:
        text = " ".join(i)
        doc = nlp(text)
        for i in doc.ents:
            text = text.replace(ent.text,'['+ent.label_+']')
        li2.append(text.split())
ner(li1)

# %%
# saving the list as json format
import json
with open("li2.json",'w') as f:
    json.dump(li2,f)

# %%
i=np.random.randint(0,len(li2))
li2[i]
# Out:
# ['<name>', 'sory', 'fit', "hal's", 'name']

# %%
# ner reduces noise by replacing common words like names,locations and others with their classification
